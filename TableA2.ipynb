# %% [markdown]
# Table A2: Main alcohol related issues in the local area (%)

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
inputFile = sourceFolder / 'ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Table A2')[0]
# Out:
# Loading in\ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx which has size 191159 bytes
# Table names: ['Table A2']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<F19 0.035>, <E15 0.042>, <E7 0.134>, <B13 0.011>, <D10 0.133>, <E17 0.038>, <E10 0.119>, <D9 0.104>, <B17 0.007>, <C9 0.088>, <E9 0.116>, <D5 0.029>, <D15 0.011>, <C11 0.019>, <F13 0.122>, <D7 0.156>, <B5 0.591>, <E19 0.006>, <F9 0.104>, <C19 0.003>, <B9 0.049>, <E11 0.078>, <E8 0.03>, <F10 0.097>, <C10 0.044>, <D14 0.04>, <B7 0.091>, <E14 0.083>, <E5 0.041>, <B11 0.015>, <F7 0.037>, <D17 0.046>, <B8 0.076>, <F14 0.107>, <C15 0.015>, <E18 0.047>, <F17 0.07>, <B14 0.008>, <B20 0.0>, <F12 0.05>, <F5 0.029>, <D11 0.039>, <F8 0.03>, <D12 0.04>, <F15 0.045>, <C22 405.0>, <C5 0.066>, <D18 0.017>, <C8 0.331>, <C20 0.0>, <F16 0.054>, <D22 388.0>, <C14 0.011>, <E20 0.0>, <C18 0.008>, <B16 0.007>, <B10 0.021>, <B22 415.0>, <F20 0.0>, <F22 329.0>, <D13 0.079>, <F11 0.111>, <D19 0.009>, <C7 0.126>, <B15 0.008>, <D20 0.003>, <D8 0.023>, <E12 0.059>, <C13 0.034>, <B6 0.099>, <F6 0.057>, <E16 0.063>, <E6 0.047>, <B12 0.015>, <C12 0.033>, <E13 0.101>, <C16 0.015>, <E22 369.0>, <B18 0.003>, <B19 0.0>, <D6 0.23>, <D16 0.041>, <C17 0.021>, <F18 0.05>, <C6 0.187>}

# %%
Alcoholissue = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Alcoholissue
# Out:
# {<E3 'Quaternary issue'>, <C3 'Secondary issue'>, <B3 'Primary issue'>, <F3 'Quinary issue'>, <D3 'Tertiary issue'>}

# %%
Alcoholrelatedissue = tab.excel_ref('A5').expand(DOWN).is_not_blank()
Alcoholrelatedissue
# Out:
# {<A15 'Joy riding'>, <A7 'Drink-driving'>, <A20 'Other'>, <A13 'Vandalism'>, <A11 'Personal safety'>, <A8 'Drinking in public places'>, <A22 'Unweighted base'>, <A10 'Underage sales of alcohol'>, <A5 'Underage drinking'>, <A17 'Spiking of drinks'>, <A14 'General disturbance'>, <A16 'Litter'>, <A25 '1. Results exclude "don\'t know" and refusals.'>, <A6 'Rowdy and drunken behaviour'>, <A18 'Indecent exposure/urinating in street'>, <A24 'Source: Northern Ireland Omnibus Survey, October 2016'>, <A9 'Alcohol use/abuse'>, <A19 'Unwanted sexual contact'>, <A12 'Theft'>}

# %%
Dimensions = [
            HDim(Alcoholissue,'Alcohol issue',DIRECTLY,ABOVE),
            HDim(Alcoholrelatedissue,'Alcohol related issue',DIRECTLY,LEFT),
            HDimConst('Measure Type', 'Percentage'),
            HDimConst('Unit','People')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#         OBS     Alcohol issue                  Alcohol related issue  \
# 0     0.591     Primary issue                      Underage drinking
# 1     0.066   Secondary issue                      Underage drinking
# 2     0.029    Tertiary issue                      Underage drinking
# 3     0.041  Quaternary issue                      Underage drinking
# 4     0.029     Quinary issue                      Underage drinking
# 5     0.099     Primary issue            Rowdy and drunken behaviour
# 6     0.187   Secondary issue            Rowdy and drunken behaviour
# 7     0.230    Tertiary issue            Rowdy and drunken behaviour
# 8     0.047  Quaternary issue            Rowdy and drunken behaviour
# 9     0.057     Quinary issue            Rowdy and drunken behaviour
# 10    0.091     Primary issue                          Drink-driving
# 11    0.126   Secondary issue                          Drink-driving
# 12    0.156    Tertiary issue                          Drink-driving
# 13    0.134  Quaternary issue                          Drink-driving
# 14    0.037     Quinary issue                          Drink-driving
# 15    0.076     Primary issue              Drinking in public places
# 16    0.331   Secondary issue              Drinking in public places
# 17    0.023    Tertiary issue              Drinking in public places
# 18    0.030  Quaternary issue              Drinking in public places
# 19    0.030     Quinary issue              Drinking in public places
# 20    0.049     Primary issue                      Alcohol use/abuse
# 21    0.088   Secondary issue                      Alcohol use/abuse
# 22    0.104    Tertiary issue                      Alcohol use/abuse
# 23    0.116  Quaternary issue                      Alcohol use/abuse
# 24    0.104     Quinary issue                      Alcohol use/abuse
# 25    0.021     Primary issue              Underage sales of alcohol
# 26    0.044   Secondary issue              Underage sales of alcohol
# 27    0.133    Tertiary issue              Underage sales of alcohol
# 28    0.119  Quaternary issue              Underage sales of alcohol
# 29    0.097     Quinary issue              Underage sales of alcohol
# ..      ...               ...                                    ...
# 55    0.007     Primary issue                                 Litter
# 56    0.015   Secondary issue                                 Litter
# 57    0.041    Tertiary issue                                 Litter
# 58    0.063  Quaternary issue                                 Litter
# 59    0.054     Quinary issue                                 Litter
# 60    0.007     Primary issue                      Spiking of drinks
# 61    0.021   Secondary issue                      Spiking of drinks
# 62    0.046    Tertiary issue                      Spiking of drinks
# 63    0.038  Quaternary issue                      Spiking of drinks
# 64    0.070     Quinary issue                      Spiking of drinks
# 65    0.003     Primary issue  Indecent exposure/urinating in street
# 66    0.008   Secondary issue  Indecent exposure/urinating in street
# 67    0.017    Tertiary issue  Indecent exposure/urinating in street
# 68    0.047  Quaternary issue  Indecent exposure/urinating in street
# 69    0.050     Quinary issue  Indecent exposure/urinating in street
# 70    0.000     Primary issue                Unwanted sexual contact
# 71    0.003   Secondary issue                Unwanted sexual contact
# 72    0.009    Tertiary issue                Unwanted sexual contact
# 73    0.006  Quaternary issue                Unwanted sexual contact
# 74    0.035     Quinary issue                Unwanted sexual contact
# 75    0.000     Primary issue                                  Other
# 76    0.000   Secondary issue                                  Other
# 77    0.003    Tertiary issue                                  Other
# 78    0.000  Quaternary issue                                  Other
# 79    0.000     Quinary issue                                  Other
# 80  415.000     Primary issue                        Unweighted base
# 81  405.000   Secondary issue                        Unweighted base
# 82  388.000    Tertiary issue                        Unweighted base
# 83  369.000  Quaternary issue                        Unweighted base
# 84  329.000     Quinary issue                        Unweighted base
#
#    Measure Type    Unit
# 0    Percentage  People
# 1    Percentage  People
# 2    Percentage  People
# 3    Percentage  People
# 4    Percentage  People
# 5    Percentage  People
# 6    Percentage  People
# 7    Percentage  People
# 8    Percentage  People
# 9    Percentage  People
# 10   Percentage  People
# 11   Percentage  People
# 12   Percentage  People
# 13   Percentage  People
# 14   Percentage  People
# 15   Percentage  People
# 16   Percentage  People
# 17   Percentage  People
# 18   Percentage  People
# 19   Percentage  People
# 20   Percentage  People
# 21   Percentage  People
# 22   Percentage  People
# 23   Percentage  People
# 24   Percentage  People
# 25   Percentage  People
# 26   Percentage  People
# 27   Percentage  People
# 28   Percentage  People
# 29   Percentage  People
# ..          ...     ...
# 55   Percentage  People
# 56   Percentage  People
# 57   Percentage  People
# 58   Percentage  People
# 59   Percentage  People
# 60   Percentage  People
# 61   Percentage  People
# 62   Percentage  People
# 63   Percentage  People
# 64   Percentage  People
# 65   Percentage  People
# 66   Percentage  People
# 67   Percentage  People
# 68   Percentage  People
# 69   Percentage  People
# 70   Percentage  People
# 71   Percentage  People
# 72   Percentage  People
# 73   Percentage  People
# 74   Percentage  People
# 75   Percentage  People
# 76   Percentage  People
# 77   Percentage  People
# 78   Percentage  People
# 79   Percentage  People
# 80   Percentage  People
# 81   Percentage  People
# 82   Percentage  People
# 83   Percentage  People
# 84   Percentage  People
#
# [85 rows x 5 columns]

# %%
new_table.columns = ['Response' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.dtypes
# Out:
# Response                 float64
# Alcohol issue             object
# Alcohol related issue     object
# Measure Type              object
# Unit                      object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Response     Alcohol issue Alcohol related issue Measure Type    Unit
# 80     415.0     Primary issue       Unweighted base   Percentage  People
# 81     405.0   Secondary issue       Unweighted base   Percentage  People
# 82     388.0    Tertiary issue       Unweighted base   Percentage  People
# 83     369.0  Quaternary issue       Unweighted base   Percentage  People
# 84     329.0     Quinary issue       Unweighted base   Percentage  People

# %%
new_table.head()
# Out:
#    Response     Alcohol issue Alcohol related issue Measure Type    Unit
# 0     0.591     Primary issue     Underage drinking   Percentage  People
# 1     0.066   Secondary issue     Underage drinking   Percentage  People
# 2     0.029    Tertiary issue     Underage drinking   Percentage  People
# 3     0.041  Quaternary issue     Underage drinking   Percentage  People
# 4     0.029     Quinary issue     Underage drinking   Percentage  People

# %%
new_table['Response'] = pd.to_numeric(new_table['Response'], errors='coerce')

# %%
new_table['Response'] = new_table['Response'].apply(str)

# %%
def user_perc(x,y):
    
    if str(x) == 'Unweighted base':
        return 'Number'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Alcohol related issue'],row['Measure Type']), axis = 1)

# %%
new_table = new_table[['Alcohol related issue','Alcohol issue','Measure Type','Response','Unit']]

# %%
new_table.head(5)
# Out:
#   Alcohol related issue     Alcohol issue Measure Type Response    Unit
# 0     Underage drinking     Primary issue   Percentage    0.591  People
# 1     Underage drinking   Secondary issue   Percentage    0.066  People
# 2     Underage drinking    Tertiary issue   Percentage    0.029  People
# 3     Underage drinking  Quaternary issue   Percentage    0.041  People
# 4     Underage drinking     Quinary issue   Percentage    0.029  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('taba2.csv'), index = False)
