# %% [markdown]
# Table A14: Overall level of confidence that enough is being done to tackle alcohol and/or drug related issues in Northern Ireland by demographics (%)

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
inputFile = sourceFolder / 'ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Table A14')[0]
# Out:
# Loading in\ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx which has size 191159 bytes
# Table names: ['Table A14']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<E48 578.0>, <C19 0.383>, <B11 0.086>, <D35 0.449>, <C39 'n<100'>, <B19 0.097>, <D11 0.515>, <E5 917.0>, <B20 0.096>, <E11 256.0>, <D19 0.52>, <E9 100.0>, <E51 236.0>, <B58 0.093>, <E21 13.0>, <B55 0.052>, <E10 240.0>, <E28 150.0>, <C11 0.398>, <E57 588.0>, <B48 0.11>, <B21 'n<100'>, <E20 442.0>, <D8 'n<100'>, <E58 329.0>, <C44 0.473>, <E19 349.0>, <E37 45.0>, <C25 0.369>, <C16 0.435>, <B56 0.128>, <E52 681.0>, <B39 'n<100'>, <C24 0.41>, <C9 0.458>, <C8 'n<100'>, <B37 'n<100'>, <E42 246.0>, <D21 'n<100'>, <C20 0.466>, <B28 0.098>, <D27 0.351>, <D16 0.467>, <D28 0.529>, <D5 0.472>, <C21 'n<100'>, <E55 269.0>, <C43 0.389>, <D58 0.467>, <D20 0.438>, <E31 439.0>, <D37 'n<100'>, <D55 0.488>, <B43 0.092>, <C36 0.412>, <C35 0.449>, <D39 'n<100'>, <D43 0.519>, <B52 0.092>, <E56 319.0>, <C55 0.46>, <E26 190.0>, <C31 0.423>, <D12 0.423>, <B35 0.102>, <E44 297.0>, <E35 265.0>, <D32 0.454>, <B16 0.098>, <D26 0.412>, <D15 0.478>, <E43 374.0>, <C38 'n<100'>, <D9 0.5>, <D24 0.54>, <D10 0.483>, <B12 0.09>, <E12 256.0>, <E32 458.0>, <D57 0.476>, <B57 0.093>, <D48 0.449>, <B32 0.099>, <D56 0.466>, <D42 0.429>, <E27 175.0>, <B10 0.116>, <C58 0.439>, <C57 0.43>, <D52 0.462>, <E15 423.0>, <B31 0.08>, <C56 0.406>, <B26 0.121>, <E25 246.0>, <B51 0.103>, <C51 0.389>, <D38 'n<100'>, <B24 0.05>, <C28 0.373>, <C15 0.433>, <B36 0.085>, <C27 0.553>, <B38 'n<100'>, <D31 0.497>, <D44 0.443>, <D25 0.535>, <B27 0.096>, <B25 0.096>, <B44 0.083>, <D36 0.503>, <E36 423.0>, <B5 0.094>, <B42 0.113>, <D47 0.51>, <E47 339.0>, <B9 0.042>, <E16 494.0>, <D51 0.507>, <C48 0.441>, <C37 'n<100'>, <E38 86.0>, <B8 'n<100'>, <C47 0.422>, <C42 0.459>, <C32 0.447>, <B47 0.068>, <C26 0.467>, <C52 0.446>, <E24 156.0>, <C10 0.401>, <E8 65.0>, <C5 0.434>, <C12 0.486>, <B15 0.088>, <E39 98.0>}

# %%
Alcoholissue = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Alcoholissue
# Out:
# {<E3 'Unweighted base'>, <D3 'Little or no confidence'>, <C3 'Some confidence'>, <B3 'Total or a lot of confidence'>}

# %%
sect = tab.excel_ref('A5').expand(DOWN).is_not_blank()
sect
# Out:
# {<A28 'Western'>, <A26 'South Eastern'>, <A62 '1. Results exclude "don\'t know" and refusals.'>, <A24 'Belfast'>, <A42 'Primary'>, <A12 '65 and over'>, <A10 '35-49'>, <A8 '16-24'>, <A57 'All urban'>, <A43 'Secondary'>, <A7 'Age of household reference person (HRP)1'>, <A23 'Health and Social Care Trust'>, <A9 '25-34'>, <A35 'Single, that is never married'>, <A52 'No disability / illness'>, <A41 'Level of qualifications'>, <A16 'Female'>, <A21 'Other'>, <A55 'Belfast'>, <A50 'Disability / illness'>, <A19 'Catholic'>, <A30 'Employment status'>, <A5 'All adults'>, <A39 'Widowed'>, <A20 'Protestant'>, <A38 'Divorced'>, <A11 '50-64'>, <A48 'No dependants'>, <A15 'Male'>, <A34 'Marital status'>, <A37 'Married and separated from husband / wife'>, <A56 'Urban, excluding Belfast'>, <A46 'Dependants'>, <A25 'Northern'>, <A44 'Tertiary'>, <A54 'Area type'>, <A31 'In paid employment'>, <A14 'Gender'>, <A32 'Not in paid employment'>, <A18 'Religion'>, <A51 'Has disability / illness'>, <A36 'Married and living with husband / wife'>, <A47 'Has dependants'>, <A58 'Rural'>, <A61 'Source: Northern Ireland Omnibus Survey, October 2016'>, <A27 'Southern'>}

# %%
category = tab.excel_ref('A').expand(DOWN).by_index([7,14,18,23,30,34,41,46,50,54])
category
# Out:
# {<A54 'Area type'>, <A23 'Health and Social Care Trust'>, <A14 'Gender'>, <A18 'Religion'>, <A41 'Level of qualifications'>, <A34 'Marital status'>, <A46 'Dependants'>, <A7 'Age of household reference person (HRP)1'>, <A30 'Employment status'>, <A50 'Disability / illness'>}

# %%
Dimensions = [
            HDim(Alcoholissue,'Level of Confidence',DIRECTLY,ABOVE),
            HDim(category,'Category',CLOSEST,ABOVE),
            HDim(sect,'Sect',DIRECTLY,LEFT),
            HDimConst('Measure Type', 'Percentage'),
            HDimConst('Unit','People'),
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS DATAMARKER           Level of Confidence  \
# 0    0.094        NaN  Total or a lot of confidence
# 1    0.434        NaN               Some confidence
# 2    0.472        NaN       Little or no confidence
# 3      917        NaN               Unweighted base
# 4               n<100  Total or a lot of confidence
# 5               n<100               Some confidence
# 6               n<100       Little or no confidence
# 7       65        NaN               Unweighted base
# 8    0.042        NaN  Total or a lot of confidence
# 9    0.458        NaN               Some confidence
# 10     0.5        NaN       Little or no confidence
# 11     100        NaN               Unweighted base
# 12   0.116        NaN  Total or a lot of confidence
# 13   0.401        NaN               Some confidence
# 14   0.483        NaN       Little or no confidence
# 15     240        NaN               Unweighted base
# 16   0.086        NaN  Total or a lot of confidence
# 17   0.398        NaN               Some confidence
# 18   0.515        NaN       Little or no confidence
# 19     256        NaN               Unweighted base
# 20    0.09        NaN  Total or a lot of confidence
# 21   0.486        NaN               Some confidence
# 22   0.423        NaN       Little or no confidence
# 23     256        NaN               Unweighted base
# 24   0.088        NaN  Total or a lot of confidence
# 25   0.433        NaN               Some confidence
# 26   0.478        NaN       Little or no confidence
# 27     423        NaN               Unweighted base
# 28   0.098        NaN  Total or a lot of confidence
# 29   0.435        NaN               Some confidence
# ..     ...        ...                           ...
# 106   0.51        NaN       Little or no confidence
# 107    339        NaN               Unweighted base
# 108   0.11        NaN  Total or a lot of confidence
# 109  0.441        NaN               Some confidence
# 110  0.449        NaN       Little or no confidence
# 111    578        NaN               Unweighted base
# 112  0.103        NaN  Total or a lot of confidence
# 113  0.389        NaN               Some confidence
# 114  0.507        NaN       Little or no confidence
# 115    236        NaN               Unweighted base
# 116  0.092        NaN  Total or a lot of confidence
# 117  0.446        NaN               Some confidence
# 118  0.462        NaN       Little or no confidence
# 119    681        NaN               Unweighted base
# 120  0.052        NaN  Total or a lot of confidence
# 121   0.46        NaN               Some confidence
# 122  0.488        NaN       Little or no confidence
# 123    269        NaN               Unweighted base
# 124  0.128        NaN  Total or a lot of confidence
# 125  0.406        NaN               Some confidence
# 126  0.466        NaN       Little or no confidence
# 127    319        NaN               Unweighted base
# 128  0.093        NaN  Total or a lot of confidence
# 129   0.43        NaN               Some confidence
# 130  0.476        NaN       Little or no confidence
# 131    588        NaN               Unweighted base
# 132  0.093        NaN  Total or a lot of confidence
# 133  0.439        NaN               Some confidence
# 134  0.467        NaN       Little or no confidence
# 135    329        NaN               Unweighted base
#
#                                      Category                      Sect  \
# 0                                        None                All adults
# 1                                        None                All adults
# 2                                        None                All adults
# 3                                        None                All adults
# 4    Age of household reference person (HRP)1                     16-24
# 5    Age of household reference person (HRP)1                     16-24
# 6    Age of household reference person (HRP)1                     16-24
# 7    Age of household reference person (HRP)1                     16-24
# 8    Age of household reference person (HRP)1                     25-34
# 9    Age of household reference person (HRP)1                     25-34
# 10   Age of household reference person (HRP)1                     25-34
# 11   Age of household reference person (HRP)1                     25-34
# 12   Age of household reference person (HRP)1                     35-49
# 13   Age of household reference person (HRP)1                     35-49
# 14   Age of household reference person (HRP)1                     35-49
# 15   Age of household reference person (HRP)1                     35-49
# 16   Age of household reference person (HRP)1                     50-64
# 17   Age of household reference person (HRP)1                     50-64
# 18   Age of household reference person (HRP)1                     50-64
# 19   Age of household reference person (HRP)1                     50-64
# 20   Age of household reference person (HRP)1               65 and over
# 21   Age of household reference person (HRP)1               65 and over
# 22   Age of household reference person (HRP)1               65 and over
# 23   Age of household reference person (HRP)1               65 and over
# 24                                     Gender                      Male
# 25                                     Gender                      Male
# 26                                     Gender                      Male
# 27                                     Gender                      Male
# 28                                     Gender                    Female
# 29                                     Gender                    Female
# ..                                        ...                       ...
# 106                                Dependants            Has dependants
# 107                                Dependants            Has dependants
# 108                                Dependants             No dependants
# 109                                Dependants             No dependants
# 110                                Dependants             No dependants
# 111                                Dependants             No dependants
# 112                      Disability / illness  Has disability / illness
# 113                      Disability / illness  Has disability / illness
# 114                      Disability / illness  Has disability / illness
# 115                      Disability / illness  Has disability / illness
# 116                      Disability / illness   No disability / illness
# 117                      Disability / illness   No disability / illness
# 118                      Disability / illness   No disability / illness
# 119                      Disability / illness   No disability / illness
# 120                                 Area type                   Belfast
# 121                                 Area type                   Belfast
# 122                                 Area type                   Belfast
# 123                                 Area type                   Belfast
# 124                                 Area type  Urban, excluding Belfast
# 125                                 Area type  Urban, excluding Belfast
# 126                                 Area type  Urban, excluding Belfast
# 127                                 Area type  Urban, excluding Belfast
# 128                                 Area type                 All urban
# 129                                 Area type                 All urban
# 130                                 Area type                 All urban
# 131                                 Area type                 All urban
# 132                                 Area type                     Rural
# 133                                 Area type                     Rural
# 134                                 Area type                     Rural
# 135                                 Area type                     Rural
#
#     Measure Type    Unit
# 0     Percentage  People
# 1     Percentage  People
# 2     Percentage  People
# 3     Percentage  People
# 4     Percentage  People
# 5     Percentage  People
# 6     Percentage  People
# 7     Percentage  People
# 8     Percentage  People
# 9     Percentage  People
# 10    Percentage  People
# 11    Percentage  People
# 12    Percentage  People
# 13    Percentage  People
# 14    Percentage  People
# 15    Percentage  People
# 16    Percentage  People
# 17    Percentage  People
# 18    Percentage  People
# 19    Percentage  People
# 20    Percentage  People
# 21    Percentage  People
# 22    Percentage  People
# 23    Percentage  People
# 24    Percentage  People
# 25    Percentage  People
# 26    Percentage  People
# 27    Percentage  People
# 28    Percentage  People
# 29    Percentage  People
# ..           ...     ...
# 106   Percentage  People
# 107   Percentage  People
# 108   Percentage  People
# 109   Percentage  People
# 110   Percentage  People
# 111   Percentage  People
# 112   Percentage  People
# 113   Percentage  People
# 114   Percentage  People
# 115   Percentage  People
# 116   Percentage  People
# 117   Percentage  People
# 118   Percentage  People
# 119   Percentage  People
# 120   Percentage  People
# 121   Percentage  People
# 122   Percentage  People
# 123   Percentage  People
# 124   Percentage  People
# 125   Percentage  People
# 126   Percentage  People
# 127   Percentage  People
# 128   Percentage  People
# 129   Percentage  People
# 130   Percentage  People
# 131   Percentage  People
# 132   Percentage  People
# 133   Percentage  People
# 134   Percentage  People
# 135   Percentage  People
#
# [136 rows x 7 columns]

# %%
new_table.columns = ['Response' if x=='OBS' else x for x in new_table.columns]

# %%
new_table = new_table[new_table['Response'] != '']

# %%
new_table.dtypes
# Out:
# Response               object
# DATAMARKER             object
# Level of Confidence    object
# Category               object
# Sect                   object
# Measure Type           object
# Unit                   object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Response DATAMARKER           Level of Confidence   Category       Sect  \
# 131      588        NaN               Unweighted base  Area type  All urban
# 132    0.093        NaN  Total or a lot of confidence  Area type      Rural
# 133    0.439        NaN               Some confidence  Area type      Rural
# 134    0.467        NaN       Little or no confidence  Area type      Rural
# 135      329        NaN               Unweighted base  Area type      Rural
#
#     Measure Type    Unit
# 131   Percentage  People
# 132   Percentage  People
# 133   Percentage  People
# 134   Percentage  People
# 135   Percentage  People

# %%
new_table.head()
# Out:
#   Response DATAMARKER           Level of Confidence  \
# 0    0.094        NaN  Total or a lot of confidence
# 1    0.434        NaN               Some confidence
# 2    0.472        NaN       Little or no confidence
# 3      917        NaN               Unweighted base
# 7       65        NaN               Unweighted base
#
#                                    Category        Sect Measure Type    Unit
# 0                                      None  All adults   Percentage  People
# 1                                      None  All adults   Percentage  People
# 2                                      None  All adults   Percentage  People
# 3                                      None  All adults   Percentage  People
# 7  Age of household reference person (HRP)1       16-24   Percentage  People

# %%
new_table['Response'] = pd.to_numeric(new_table['Response'], errors='coerce')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Response'] = new_table['Response'].apply(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def user_perc(x,y):
    
    if str(x) == 'Unweighted base':
        return 'Number'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Level of Confidence'],row['Measure Type']), axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table['Category'].fillna('All', inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
new_table['Demographic'] = new_table['Category'] + '/' + new_table['Sect']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table = new_table[['Demographic','Level of Confidence','Measure Type','Response','Unit']]

# %%
new_table.head(5)
# Out:
#                                       Demographic  \
# 0                                  All/All adults
# 1                                  All/All adults
# 2                                  All/All adults
# 3                                  All/All adults
# 7  Age of household reference person (HRP)1/16-24
#
#             Level of Confidence Measure Type Response    Unit
# 0  Total or a lot of confidence   Percentage    0.094  People
# 1               Some confidence   Percentage    0.434  People
# 2       Little or no confidence   Percentage    0.472  People
# 3               Unweighted base       Number    917.0  People
# 7               Unweighted base       Number     65.0  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('taba14.csv'), index = False)
