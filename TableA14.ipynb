# %% [markdown]
# Table A14: Overall Alcohol related issue response that enough is being done to tackle alcohol and/or drug related issues in Northern Ireland by demographics (%)

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
inputFile = sourceFolder / 'ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
Value = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(Value.content)

# %% [markdown]
# https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Table A14')[0]
# Out:
# Loading in\ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx which has size 191159 bytes
# Table names: ['Table A14']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<C32 0.447>, <D52 0.462>, <E20 442.0>, <C38 'n<100'>, <E15 423.0>, <B31 0.08>, <C56 0.406>, <D12 0.423>, <C26 0.467>, <E25 246.0>, <B51 0.103>, <C10 0.401>, <C25 0.369>, <E35 265.0>, <C51 0.389>, <C5 0.434>, <D32 0.454>, <B37 'n<100'>, <C9 0.458>, <E48 578.0>, <E42 246.0>, <B11 0.086>, <D35 0.449>, <B25 0.096>, <D57 0.476>, <E51 236.0>, <B5 0.094>, <E47 339.0>, <B9 0.042>, <D55 0.488>, <C11 0.398>, <C58 0.439>, <E57 588.0>, <C35 0.449>, <D43 0.519>, <B26 0.121>, <E56 319.0>, <B8 'n<100'>, <E38 86.0>, <D8 'n<100'>, <E19 349.0>, <C55 0.46>, <E37 45.0>, <B56 0.128>, <C15 0.433>, <B47 0.068>, <B36 0.085>, <C27 0.553>, <D38 'n<100'>, <C8 'n<100'>, <C20 0.466>, <E44 297.0>, <E8 65.0>, <C12 0.486>, <B15 0.088>, <D28 0.529>, <E39 98.0>, <D5 0.472>, <D26 0.412>, <B42 0.113>, <D24 0.54>, <D47 0.51>, <D11 0.515>, <E5 917.0>, <E32 458.0>, <E11 256.0>, <E16 494.0>, <B57 0.093>, <D39 'n<100'>, <D51 0.507>, <B32 0.099>, <C48 0.441>, <C47 0.422>, <C42 0.459>, <B48 0.11>, <E26 190.0>, <C57 0.43>, <C37 'n<100'>, <C31 0.423>, <C52 0.446>, <E24 156.0>, <C44 0.473>, <C28 0.373>, <B38 'n<100'>, <C24 0.41>, <D15 0.478>, <E43 374.0>, <D9 0.5>, <B28 0.098>, <D27 0.351>, <C39 'n<100'>, <B20 0.096>, <D19 0.52>, <B44 0.083>, <D36 0.503>, <D48 0.449>, <E55 269.0>, <B58 0.093>, <E21 13.0>, <D58 0.467>, <E28 150.0>, <D20 0.438>, <E10 240.0>, <B55 0.052>, <E31 439.0>, <B10 0.116>, <E58 329.0>, <C16 0.435>, <B24 0.05>, <E52 681.0>, <B21 'n<100'>, <D31 0.497>, <B35 0.102>, <D37 'n<100'>, <D44 0.443>, <D25 0.535>, <B27 0.096>, <D16 0.467>, <B16 0.098>, <C19 0.383>, <E36 423.0>, <C43 0.389>, <D10 0.483>, <B12 0.09>, <B19 0.097>, <D21 'n<100'>, <E12 256.0>, <B43 0.092>, <C36 0.412>, <E9 100.0>, <B39 'n<100'>, <B52 0.092>, <D56 0.466>, <D42 0.429>, <C21 'n<100'>, <E27 175.0>}

# %%
Alcoholissue = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Alcoholissue
# Out:
# {<D3 'Little or no confidence'>, <E3 'Unweighted base'>, <C3 'Some confidence'>, <B3 'Total or a lot of confidence'>}

# %%
sect = tab.excel_ref('A5').expand(DOWN).is_not_blank()
sect
# Out:
# {<A35 'Single, that is never married'>, <A10 '35-49'>, <A62 '1. Results exclude "don\'t know" and refusals.'>, <A42 'Primary'>, <A57 'All urban'>, <A55 'Belfast'>, <A51 'Has disability / illness'>, <A41 'Level of qualifications'>, <A32 'Not in paid employment'>, <A54 'Area type'>, <A25 'Northern'>, <A43 'Secondary'>, <A56 'Urban, excluding Belfast'>, <A48 'No dependants'>, <A9 '25-34'>, <A46 'Dependants'>, <A61 'Source: Northern Ireland Omnibus Survey, October 2016'>, <A30 'Employment status'>, <A39 'Widowed'>, <A20 'Protestant'>, <A37 'Married and separated from husband / wife'>, <A8 '16-24'>, <A21 'Other'>, <A52 'No disability / illness'>, <A27 'Southern'>, <A15 'Male'>, <A34 'Marital status'>, <A31 'In paid employment'>, <A58 'Rural'>, <A14 'Gender'>, <A16 'Female'>, <A44 'Tertiary'>, <A36 'Married and living with husband / wife'>, <A11 '50-64'>, <A7 'Age of household reference person (HRP)1'>, <A50 'Disability / illness'>, <A23 'Health and Social Care Trust'>, <A19 'Catholic'>, <A5 'All adults'>, <A28 'Western'>, <A26 'South Eastern'>, <A47 'Has dependants'>, <A18 'Religion'>, <A24 'Belfast'>, <A38 'Divorced'>, <A12 '65 and over'>}

# %%
category = tab.excel_ref('A').expand(DOWN).by_index([7,14,18,23,30,34,41,46,50,54])
category
# Out:
# {<A7 'Age of household reference person (HRP)1'>, <A50 'Disability / illness'>, <A23 'Health and Social Care Trust'>, <A54 'Area type'>, <A34 'Marital status'>, <A46 'Dependants'>, <A41 'Level of qualifications'>, <A18 'Religion'>, <A30 'Employment status'>, <A14 'Gender'>}

# %%
Dimensions = [
            HDim(Alcoholissue,'Alcohol related issue response',DIRECTLY,ABOVE),
            HDim(category,'Category',CLOSEST,ABOVE),
            HDim(sect,'Sect',DIRECTLY,LEFT),
            HDimConst('Measure Type', 'Percent'),
            HDimConst('Unit','People'),
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS DATAMARKER Alcohol related issue response  \
# 0    0.094        NaN   Total or a lot of confidence
# 1    0.434        NaN                Some confidence
# 2    0.472        NaN        Little or no confidence
# 3      917        NaN                Unweighted base
# 4               n<100   Total or a lot of confidence
# 5               n<100                Some confidence
# 6               n<100        Little or no confidence
# 7       65        NaN                Unweighted base
# 8    0.042        NaN   Total or a lot of confidence
# 9    0.458        NaN                Some confidence
# 10     0.5        NaN        Little or no confidence
# 11     100        NaN                Unweighted base
# 12   0.116        NaN   Total or a lot of confidence
# 13   0.401        NaN                Some confidence
# 14   0.483        NaN        Little or no confidence
# 15     240        NaN                Unweighted base
# 16   0.086        NaN   Total or a lot of confidence
# 17   0.398        NaN                Some confidence
# 18   0.515        NaN        Little or no confidence
# 19     256        NaN                Unweighted base
# 20    0.09        NaN   Total or a lot of confidence
# 21   0.486        NaN                Some confidence
# 22   0.423        NaN        Little or no confidence
# 23     256        NaN                Unweighted base
# 24   0.088        NaN   Total or a lot of confidence
# 25   0.433        NaN                Some confidence
# 26   0.478        NaN        Little or no confidence
# 27     423        NaN                Unweighted base
# 28   0.098        NaN   Total or a lot of confidence
# 29   0.435        NaN                Some confidence
# ..     ...        ...                            ...
# 106   0.51        NaN        Little or no confidence
# 107    339        NaN                Unweighted base
# 108   0.11        NaN   Total or a lot of confidence
# 109  0.441        NaN                Some confidence
# 110  0.449        NaN        Little or no confidence
# 111    578        NaN                Unweighted base
# 112  0.103        NaN   Total or a lot of confidence
# 113  0.389        NaN                Some confidence
# 114  0.507        NaN        Little or no confidence
# 115    236        NaN                Unweighted base
# 116  0.092        NaN   Total or a lot of confidence
# 117  0.446        NaN                Some confidence
# 118  0.462        NaN        Little or no confidence
# 119    681        NaN                Unweighted base
# 120  0.052        NaN   Total or a lot of confidence
# 121   0.46        NaN                Some confidence
# 122  0.488        NaN        Little or no confidence
# 123    269        NaN                Unweighted base
# 124  0.128        NaN   Total or a lot of confidence
# 125  0.406        NaN                Some confidence
# 126  0.466        NaN        Little or no confidence
# 127    319        NaN                Unweighted base
# 128  0.093        NaN   Total or a lot of confidence
# 129   0.43        NaN                Some confidence
# 130  0.476        NaN        Little or no confidence
# 131    588        NaN                Unweighted base
# 132  0.093        NaN   Total or a lot of confidence
# 133  0.439        NaN                Some confidence
# 134  0.467        NaN        Little or no confidence
# 135    329        NaN                Unweighted base
#
#                                      Category                      Sect  \
# 0                                        None                All adults
# 1                                        None                All adults
# 2                                        None                All adults
# 3                                        None                All adults
# 4    Age of household reference person (HRP)1                     16-24
# 5    Age of household reference person (HRP)1                     16-24
# 6    Age of household reference person (HRP)1                     16-24
# 7    Age of household reference person (HRP)1                     16-24
# 8    Age of household reference person (HRP)1                     25-34
# 9    Age of household reference person (HRP)1                     25-34
# 10   Age of household reference person (HRP)1                     25-34
# 11   Age of household reference person (HRP)1                     25-34
# 12   Age of household reference person (HRP)1                     35-49
# 13   Age of household reference person (HRP)1                     35-49
# 14   Age of household reference person (HRP)1                     35-49
# 15   Age of household reference person (HRP)1                     35-49
# 16   Age of household reference person (HRP)1                     50-64
# 17   Age of household reference person (HRP)1                     50-64
# 18   Age of household reference person (HRP)1                     50-64
# 19   Age of household reference person (HRP)1                     50-64
# 20   Age of household reference person (HRP)1               65 and over
# 21   Age of household reference person (HRP)1               65 and over
# 22   Age of household reference person (HRP)1               65 and over
# 23   Age of household reference person (HRP)1               65 and over
# 24                                     Gender                      Male
# 25                                     Gender                      Male
# 26                                     Gender                      Male
# 27                                     Gender                      Male
# 28                                     Gender                    Female
# 29                                     Gender                    Female
# ..                                        ...                       ...
# 106                                Dependants            Has dependants
# 107                                Dependants            Has dependants
# 108                                Dependants             No dependants
# 109                                Dependants             No dependants
# 110                                Dependants             No dependants
# 111                                Dependants             No dependants
# 112                      Disability / illness  Has disability / illness
# 113                      Disability / illness  Has disability / illness
# 114                      Disability / illness  Has disability / illness
# 115                      Disability / illness  Has disability / illness
# 116                      Disability / illness   No disability / illness
# 117                      Disability / illness   No disability / illness
# 118                      Disability / illness   No disability / illness
# 119                      Disability / illness   No disability / illness
# 120                                 Area type                   Belfast
# 121                                 Area type                   Belfast
# 122                                 Area type                   Belfast
# 123                                 Area type                   Belfast
# 124                                 Area type  Urban, excluding Belfast
# 125                                 Area type  Urban, excluding Belfast
# 126                                 Area type  Urban, excluding Belfast
# 127                                 Area type  Urban, excluding Belfast
# 128                                 Area type                 All urban
# 129                                 Area type                 All urban
# 130                                 Area type                 All urban
# 131                                 Area type                 All urban
# 132                                 Area type                     Rural
# 133                                 Area type                     Rural
# 134                                 Area type                     Rural
# 135                                 Area type                     Rural
#
#     Measure Type    Unit
# 0        Percent  People
# 1        Percent  People
# 2        Percent  People
# 3        Percent  People
# 4        Percent  People
# 5        Percent  People
# 6        Percent  People
# 7        Percent  People
# 8        Percent  People
# 9        Percent  People
# 10       Percent  People
# 11       Percent  People
# 12       Percent  People
# 13       Percent  People
# 14       Percent  People
# 15       Percent  People
# 16       Percent  People
# 17       Percent  People
# 18       Percent  People
# 19       Percent  People
# 20       Percent  People
# 21       Percent  People
# 22       Percent  People
# 23       Percent  People
# 24       Percent  People
# 25       Percent  People
# 26       Percent  People
# 27       Percent  People
# 28       Percent  People
# 29       Percent  People
# ..           ...     ...
# 106      Percent  People
# 107      Percent  People
# 108      Percent  People
# 109      Percent  People
# 110      Percent  People
# 111      Percent  People
# 112      Percent  People
# 113      Percent  People
# 114      Percent  People
# 115      Percent  People
# 116      Percent  People
# 117      Percent  People
# 118      Percent  People
# 119      Percent  People
# 120      Percent  People
# 121      Percent  People
# 122      Percent  People
# 123      Percent  People
# 124      Percent  People
# 125      Percent  People
# 126      Percent  People
# 127      Percent  People
# 128      Percent  People
# 129      Percent  People
# 130      Percent  People
# 131      Percent  People
# 132      Percent  People
# 133      Percent  People
# 134      Percent  People
# 135      Percent  People
#
# [136 rows x 7 columns]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table = new_table[new_table['Value'].notnull()]

# %%
new_table['Value'] = pd.to_numeric(new_table['Value'], errors='coerce')

# %%
new_table['Value'] = new_table['Value'].apply(str)

# %%
def user_perc(x,y):
    
    if str(x) == 'Unweighted base':
        return 'Count'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Alcohol related issue response'],row['Measure Type']), axis = 1)

# %%
new_table['Category'] = new_table['Category'].str.rstrip('1')

# %%
new_table['Demographic1'] = new_table['Category'].fillna('') + ' - ' + new_table['Sect'].fillna('')

# %%
new_table['Demographic1'] = new_table['Demographic1'].str.lstrip(' - ')

# %%
new_table = new_table[['Demographic1','Alcohol related issue response','Measure Type','Value','Unit']]

# %%
new_table
# Out:
#                                           Demographic1  \
# 0                                           All adults
# 1                                           All adults
# 2                                           All adults
# 3                                           All adults
# 4      Age of household reference person (HRP) - 16-24
# 5      Age of household reference person (HRP) - 16-24
# 6      Age of household reference person (HRP) - 16-24
# 7      Age of household reference person (HRP) - 16-24
# 8      Age of household reference person (HRP) - 25-34
# 9      Age of household reference person (HRP) - 25-34
# 10     Age of household reference person (HRP) - 25-34
# 11     Age of household reference person (HRP) - 25-34
# 12     Age of household reference person (HRP) - 35-49
# 13     Age of household reference person (HRP) - 35-49
# 14     Age of household reference person (HRP) - 35-49
# 15     Age of household reference person (HRP) - 35-49
# 16     Age of household reference person (HRP) - 50-64
# 17     Age of household reference person (HRP) - 50-64
# 18     Age of household reference person (HRP) - 50-64
# 19     Age of household reference person (HRP) - 50-64
# 20   Age of household reference person (HRP) - 65 a...
# 21   Age of household reference person (HRP) - 65 a...
# 22   Age of household reference person (HRP) - 65 a...
# 23   Age of household reference person (HRP) - 65 a...
# 24                                       Gender - Male
# 25                                       Gender - Male
# 26                                       Gender - Male
# 27                                       Gender - Male
# 28                                     Gender - Female
# 29                                     Gender - Female
# ..                                                 ...
# 106                        Dependants - Has dependants
# 107                        Dependants - Has dependants
# 108                         Dependants - No dependants
# 109                         Dependants - No dependants
# 110                         Dependants - No dependants
# 111                         Dependants - No dependants
# 112    Disability / illness - Has disability / illness
# 113    Disability / illness - Has disability / illness
# 114    Disability / illness - Has disability / illness
# 115    Disability / illness - Has disability / illness
# 116     Disability / illness - No disability / illness
# 117     Disability / illness - No disability / illness
# 118     Disability / illness - No disability / illness
# 119     Disability / illness - No disability / illness
# 120                                Area type - Belfast
# 121                                Area type - Belfast
# 122                                Area type - Belfast
# 123                                Area type - Belfast
# 124               Area type - Urban, excluding Belfast
# 125               Area type - Urban, excluding Belfast
# 126               Area type - Urban, excluding Belfast
# 127               Area type - Urban, excluding Belfast
# 128                              Area type - All urban
# 129                              Area type - All urban
# 130                              Area type - All urban
# 131                              Area type - All urban
# 132                                  Area type - Rural
# 133                                  Area type - Rural
# 134                                  Area type - Rural
# 135                                  Area type - Rural
#
#     Alcohol related issue response Measure Type  Value    Unit
# 0     Total or a lot of confidence      Percent  0.094  People
# 1                  Some confidence      Percent  0.434  People
# 2          Little or no confidence      Percent  0.472  People
# 3                  Unweighted base        Count  917.0  People
# 4     Total or a lot of confidence      Percent    nan  People
# 5                  Some confidence      Percent    nan  People
# 6          Little or no confidence      Percent    nan  People
# 7                  Unweighted base        Count   65.0  People
# 8     Total or a lot of confidence      Percent  0.042  People
# 9                  Some confidence      Percent  0.458  People
# 10         Little or no confidence      Percent    0.5  People
# 11                 Unweighted base        Count  100.0  People
# 12    Total or a lot of confidence      Percent  0.116  People
# 13                 Some confidence      Percent  0.401  People
# 14         Little or no confidence      Percent  0.483  People
# 15                 Unweighted base        Count  240.0  People
# 16    Total or a lot of confidence      Percent  0.086  People
# 17                 Some confidence      Percent  0.398  People
# 18         Little or no confidence      Percent  0.515  People
# 19                 Unweighted base        Count  256.0  People
# 20    Total or a lot of confidence      Percent   0.09  People
# 21                 Some confidence      Percent  0.486  People
# 22         Little or no confidence      Percent  0.423  People
# 23                 Unweighted base        Count  256.0  People
# 24    Total or a lot of confidence      Percent  0.088  People
# 25                 Some confidence      Percent  0.433  People
# 26         Little or no confidence      Percent  0.478  People
# 27                 Unweighted base        Count  423.0  People
# 28    Total or a lot of confidence      Percent  0.098  People
# 29                 Some confidence      Percent  0.435  People
# ..                             ...          ...    ...     ...
# 106        Little or no confidence      Percent   0.51  People
# 107                Unweighted base        Count  339.0  People
# 108   Total or a lot of confidence      Percent   0.11  People
# 109                Some confidence      Percent  0.441  People
# 110        Little or no confidence      Percent  0.449  People
# 111                Unweighted base        Count  578.0  People
# 112   Total or a lot of confidence      Percent  0.103  People
# 113                Some confidence      Percent  0.389  People
# 114        Little or no confidence      Percent  0.507  People
# 115                Unweighted base        Count  236.0  People
# 116   Total or a lot of confidence      Percent  0.092  People
# 117                Some confidence      Percent  0.446  People
# 118        Little or no confidence      Percent  0.462  People
# 119                Unweighted base        Count  681.0  People
# 120   Total or a lot of confidence      Percent  0.052  People
# 121                Some confidence      Percent   0.46  People
# 122        Little or no confidence      Percent  0.488  People
# 123                Unweighted base        Count  269.0  People
# 124   Total or a lot of confidence      Percent  0.128  People
# 125                Some confidence      Percent  0.406  People
# 126        Little or no confidence      Percent  0.466  People
# 127                Unweighted base        Count  319.0  People
# 128   Total or a lot of confidence      Percent  0.093  People
# 129                Some confidence      Percent   0.43  People
# 130        Little or no confidence      Percent  0.476  People
# 131                Unweighted base        Count  588.0  People
# 132   Total or a lot of confidence      Percent  0.093  People
# 133                Some confidence      Percent  0.439  People
# 134        Little or no confidence      Percent  0.467  People
# 135                Unweighted base        Count  329.0  People
#
# [136 rows x 5 columns]

# %%
import urllib.request as request
import csv
r = request.urlopen('https://raw.githubusercontent.com/ONS-OpenData/ref_alcohol/master/codelists/demographic.csv').read().decode('utf8').split("\n")
reader = csv.reader(r)
for line in reader:
    print(line)
# Out:
# ['Label', 'Notation', 'Parent Notation', 'Sort Priority']
# ['All adults', 'all-adults', '', '1']
# ['Age of household reference person (HRP) - 16-24', 'hrp/16-24', '', '2']
# ['Age of household reference person (HRP) - 25-34', 'hrp/25-34', '', '3']
# ['Age of household reference person (HRP) - 35-49', 'hrp/35-49', '', '4']
# ['Age of household reference person (HRP) - 50-64', 'hrp/50-64', '', '5']
# ['Age of household reference person (HRP) - 65 and over', 'hrp/65plus', '', '6']
# ['Gender - Male', 'male', '', '7']
# ['Gender - Female', 'female', '', '8']
# ['Religion - Catholic', 'catholic', '', '9']
# ['Religion - Protestant', 'protestant', '', '10']
# ['Religion - Other', 'other', '', '11']
# ['Health and Social Care Trust - Belfast', 'hsct/belfast', '', '12']
# ['Health and Social Care Trust - Northern', 'hsct/northern', '', '13']
# ['Health and Social Care Trust - South Eastern', 'hsct/south-eastern', '', '14']
# ['Health and Social Care Trust - Southern', 'hsct/southern', '', '15']
# ['Health and Social Care Trust - Western', 'hsct/western', '', '16']
# ['Employment status - In paid employment', 'paid-employment', '', '17']
# ['Employment status - Not in paid employment', 'not-in-paid-employment', '', '18']
# ['Marital status - Single, that is never married', 'single', '', '19']
# ['Marital status - Married and living with husband / wife', 'married', '', '20']
# ['Marital status - Married and separated from husband / wife', 'married-separated', '', '21']
# ['Marital status - Divorced', 'divorced', '', '22']
# ['Marital status - Widowed', 'widowed', '', '23']
# ['Level of qualifications - Primary', 'primary', '', '24']
# ['Level of qualifications - Secondary', 'secondary', '', '25']
# ['Level of qualifications - Tertiary', 'tertiary', '', '26']
# ['Dependants - Has dependants', 'dependants', '', '27']
# ['Dependants - No dependants', 'no-dependants', '', '28']
# ['Disability / illness - Has disability / illness', 'disability', '', '29']
# ['Disability / illness - No disability / illness', 'no-disability', '', '30']
# ['Area type - Belfast', 'belfast', '', '31']
# ['Area type - Urban, excluding Belfast', 'urban-excl-belfast', '', '32']
# ['Area type - All urban', 'all-urban', '', '33']
# ['Area type - Rural', 'rural', '', '34']

# %%
import io
import requests
url="https://raw.githubusercontent.com/ONS-OpenData/ref_alcohol/master/codelists/demographic.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
Final_table = pd.merge(new_table, c, how = 'left', left_on = 'Demographic1', right_on = 'Label')

# %%
Final_table.columns = ['Demographic' if x=='Notation' else x for x in Final_table.columns]

# %%
Final_table['Alcohol related issue response'] = Final_table['Alcohol related issue response'].map(
    lambda x: {
        'Total or a lot of confidence' : 'total-confidence', 
        'Some confidence' : 'some-confidence',
        'Little or no confidence': 'no-confidence' ,
        'Unweighted base': 'unweighted-base'
        }.get(x, x))

# %%
Final_table = Final_table[['Demographic','Alcohol related issue response','Measure Type','Value','Unit']]

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

Final_table.to_csv(destinationFolder / ('table14.csv'), index = False)

# %%
Final_table
# Out:
#             Demographic Alcohol related issue response Measure Type  Value  \
# 0            all-adults               total-confidence      Percent  0.094
# 1            all-adults                some-confidence      Percent  0.434
# 2            all-adults                  no-confidence      Percent  0.472
# 3            all-adults                unweighted-base        Count  917.0
# 4             hrp/16-24               total-confidence      Percent    nan
# 5             hrp/16-24                some-confidence      Percent    nan
# 6             hrp/16-24                  no-confidence      Percent    nan
# 7             hrp/16-24                unweighted-base        Count   65.0
# 8             hrp/25-34               total-confidence      Percent  0.042
# 9             hrp/25-34                some-confidence      Percent  0.458
# 10            hrp/25-34                  no-confidence      Percent    0.5
# 11            hrp/25-34                unweighted-base        Count  100.0
# 12            hrp/35-49               total-confidence      Percent  0.116
# 13            hrp/35-49                some-confidence      Percent  0.401
# 14            hrp/35-49                  no-confidence      Percent  0.483
# 15            hrp/35-49                unweighted-base        Count  240.0
# 16            hrp/50-64               total-confidence      Percent  0.086
# 17            hrp/50-64                some-confidence      Percent  0.398
# 18            hrp/50-64                  no-confidence      Percent  0.515
# 19            hrp/50-64                unweighted-base        Count  256.0
# 20           hrp/65plus               total-confidence      Percent   0.09
# 21           hrp/65plus                some-confidence      Percent  0.486
# 22           hrp/65plus                  no-confidence      Percent  0.423
# 23           hrp/65plus                unweighted-base        Count  256.0
# 24                 male               total-confidence      Percent  0.088
# 25                 male                some-confidence      Percent  0.433
# 26                 male                  no-confidence      Percent  0.478
# 27                 male                unweighted-base        Count  423.0
# 28               female               total-confidence      Percent  0.098
# 29               female                some-confidence      Percent  0.435
# ..                  ...                            ...          ...    ...
# 106          dependants                  no-confidence      Percent   0.51
# 107          dependants                unweighted-base        Count  339.0
# 108       no-dependants               total-confidence      Percent   0.11
# 109       no-dependants                some-confidence      Percent  0.441
# 110       no-dependants                  no-confidence      Percent  0.449
# 111       no-dependants                unweighted-base        Count  578.0
# 112          disability               total-confidence      Percent  0.103
# 113          disability                some-confidence      Percent  0.389
# 114          disability                  no-confidence      Percent  0.507
# 115          disability                unweighted-base        Count  236.0
# 116       no-disability               total-confidence      Percent  0.092
# 117       no-disability                some-confidence      Percent  0.446
# 118       no-disability                  no-confidence      Percent  0.462
# 119       no-disability                unweighted-base        Count  681.0
# 120             belfast               total-confidence      Percent  0.052
# 121             belfast                some-confidence      Percent   0.46
# 122             belfast                  no-confidence      Percent  0.488
# 123             belfast                unweighted-base        Count  269.0
# 124  urban-excl-belfast               total-confidence      Percent  0.128
# 125  urban-excl-belfast                some-confidence      Percent  0.406
# 126  urban-excl-belfast                  no-confidence      Percent  0.466
# 127  urban-excl-belfast                unweighted-base        Count  319.0
# 128           all-urban               total-confidence      Percent  0.093
# 129           all-urban                some-confidence      Percent   0.43
# 130           all-urban                  no-confidence      Percent  0.476
# 131           all-urban                unweighted-base        Count  588.0
# 132               rural               total-confidence      Percent  0.093
# 133               rural                some-confidence      Percent  0.439
# 134               rural                  no-confidence      Percent  0.467
# 135               rural                unweighted-base        Count  329.0
#
#        Unit
# 0    People
# 1    People
# 2    People
# 3    People
# 4    People
# 5    People
# 6    People
# 7    People
# 8    People
# 9    People
# 10   People
# 11   People
# 12   People
# 13   People
# 14   People
# 15   People
# 16   People
# 17   People
# 18   People
# 19   People
# 20   People
# 21   People
# 22   People
# 23   People
# 24   People
# 25   People
# 26   People
# 27   People
# 28   People
# 29   People
# ..      ...
# 106  People
# 107  People
# 108  People
# 109  People
# 110  People
# 111  People
# 112  People
# 113  People
# 114  People
# 115  People
# 116  People
# 117  People
# 118  People
# 119  People
# 120  People
# 121  People
# 122  People
# 123  People
# 124  People
# 125  People
# 126  People
# 127  People
# 128  People
# 129  People
# 130  People
# 131  People
# 132  People
# 133  People
# 134  People
# 135  People
#
# [136 rows x 5 columns]
