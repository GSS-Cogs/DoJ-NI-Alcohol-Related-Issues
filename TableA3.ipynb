# %% [markdown]
# Table A3: Perceptions of change in the level of alcohol related issues in the local area in the last 12 months by demographics (%)

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
inputFile = sourceFolder / 'ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
Value = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(Value.content)

# %% [markdown]
# https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Table A3')[0]
# Out:
# Loading in\ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx which has size 191159 bytes
# Table names: ['Table A3']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<D5 0.106>, <B12 0.071>, <C32 0.807>, <D36 0.089>, <C31 0.857>, <B36 0.054>, <C26 0.814>, <C25 0.871>, <C48 0.82>, <C28 0.745>, <B47 0.055>, <E39 100.0>, <E57 561.0>, <C16 0.819>, <D27 0.063>, <D37 'n<100'>, <E10 230.0>, <C15 0.828>, <D42 0.09>, <C5 0.824>, <B44 0.053>, <E43 365.0>, <E47 322.0>, <B57 0.094>, <B19 0.072>, <Q25 'Total'>, <C57 0.778>, <B43 0.087>, <B21 'n<100'>, <D43 0.121>, <E26 187.0>, <E28 144.0>, <C8 'n<100'>, <B35 0.093>, <B24 0.115>, <C38 'n<100'>, <E16 465.0>, <E15 416.0>, <B5 0.07>, <D20 0.088>, <B31 0.062>, <E42 238.0>, <D12 0.093>, <C43 0.792>, <B37 'n<100'>, <B16 0.077>, <E51 230.0>, <B55 0.089>, <D26 0.113>, <B10 0.06>, <C20 0.85>, <B56 0.098>, <D55 0.131>, <E37 40.0>, <E32 446.0>, <D56 0.124>, <E48 559.0>, <D8 'n<100'>, <B15 0.063>, <D39 0.048>, <E38 85.0>, <E31 416.0>, <D58 0.071>, <E25 238.0>, <D16 0.104>, <E11 244.0>, <B58 0.032>, <E27 165.0>, <D10 0.108>, <Q36 'Total'>, <D51 0.132>, <E24 147.0>, <Q42 1.0>, <C47 0.83>, <D28 0.161>, <C42 0.847>, <D11 0.091>, <C44 0.851>, <E19 337.0>, <D38 'n<100'>, <E44 278.0>, <D48 0.099>, <C27 0.891>, <C10 0.832>, <B39 0.065>, <B51 0.076>, <C12 0.836>, <D57 0.129>, <E55 257.0>, <D21 'n<100'>, <E36 408.0>, <C11 0.854>, <B42 0.063>, <D44 0.096>, <C58 0.897>, <E9 90.0>, <C56 0.778>, <C9 'n<100'>, <D35 0.152>, <C55 0.781>, <E21 13.0>, <D31 0.081>, <C21 'n<100'>, <D25 0.085>, <E35 248.0>, <B27 0.046>, <C37 'n<100'>, <E20 428.0>, <E56 304.0>, <B25 0.044>, <B9 'n<100'>, <C24 0.763>, <B32 0.075>, <E5 881.0>, <E52 651.0>, <D32 0.118>, <B20 0.062>, <E8 57.0>, <B11 0.055>, <B48 0.081>, <C52 0.834>, <C39 0.887>, <B28 0.094>, <C51 0.792>, <D24 0.122>, <B38 'n<100'>, <B52 0.069>, <D47 0.115>, <D52 0.098>, <C19 0.791>, <B8 'n<100'>, <C36 0.857>, <E58 320.0>, <C35 0.755>, <D9 'n<100'>, <E12 260.0>, <D19 0.136>, <D15 0.11>, <B26 0.073>}

# %%
Alcoholissue = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Alcoholissue
# Out:
# {<C3 'About the same'>, <E3 'Unweighted base'>, <D3 'Worse'>, <B3 'Better'>}

# %%
sect = tab.excel_ref('A5').expand(DOWN).is_not_blank()
sect
# Out:
# {<A7 'Age of household reference person (HRP)1'>, <A27 'Southern'>, <A36 'Married and living with husband / wife'>, <A51 'Has disability / illness'>, <A50 'Disability / illness'>, <A21 'Other'>, <A24 'Belfast'>, <A10 '35-49'>, <A34 'Marital status'>, <A31 'In paid employment'>, <A43 'Secondary'>, <A37 'Married and separated from husband / wife'>, <A28 'Western'>, <A44 'Tertiary'>, <A23 'Health and Social Care Trust'>, <A32 'Not in paid employment'>, <A35 'Single, that is never married'>, <A61 'Source: Northern Ireland Omnibus Survey, October 2016'>, <A56 'Urban, excluding Belfast'>, <A30 'Employment status'>, <A5 'All adults'>, <A54 'Area type'>, <A46 'Dependants'>, <A15 'Male'>, <A25 'Northern'>, <A8 '16-24'>, <A18 'Religion'>, <A39 'Widowed'>, <A16 'Female'>, <A12 '65 and over'>, <A41 'Level of qualifications'>, <A26 'South Eastern'>, <A42 'Primary'>, <A47 'Has dependants'>, <A14 'Gender'>, <A55 'Belfast'>, <A62 '1. Results exclude "don\'t know" and refusals.'>, <A57 'All urban'>, <A20 'Protestant'>, <A52 'No disability / illness'>, <A19 'Catholic'>, <A11 '50-64'>, <A58 'Rural'>, <A38 'Divorced'>, <A9 '25-34'>, <A48 'No dependants'>}

# %%
category = tab.excel_ref('A').expand(DOWN).by_index([7,14,18,23,30,34,41,46,50,54])
category
# Out:
# {<A7 'Age of household reference person (HRP)1'>, <A54 'Area type'>, <A46 'Dependants'>, <A14 'Gender'>, <A50 'Disability / illness'>, <A18 'Religion'>, <A23 'Health and Social Care Trust'>, <A30 'Employment status'>, <A34 'Marital status'>, <A41 'Level of qualifications'>}

# %%
Dimensions = [
            HDim(Alcoholissue,'Alcohol related issue response',DIRECTLY,ABOVE),
            HDim(category,'Category',CLOSEST,ABOVE),
            HDim(sect,'Sect',DIRECTLY,LEFT),
            HDimConst('Measure Type', 'Percent'),
            HDimConst('Unit','People'),
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS DATAMARKER Alcohol related issue response  \
# 0     0.07        NaN                         Better
# 1    0.824        NaN                 About the same
# 2    0.106        NaN                          Worse
# 3      881        NaN                Unweighted base
# 4               n<100                         Better
# 5               n<100                 About the same
# 6               n<100                          Worse
# 7       57        NaN                Unweighted base
# 8               n<100                         Better
# 9               n<100                 About the same
# 10              n<100                          Worse
# 11      90        NaN                Unweighted base
# 12    0.06        NaN                         Better
# 13   0.832        NaN                 About the same
# 14   0.108        NaN                          Worse
# 15     230        NaN                Unweighted base
# 16   0.055        NaN                         Better
# 17   0.854        NaN                 About the same
# 18   0.091        NaN                          Worse
# 19     244        NaN                Unweighted base
# 20   0.071        NaN                         Better
# 21   0.836        NaN                 About the same
# 22   0.093        NaN                          Worse
# 23     260        NaN                Unweighted base
# 24   0.063        NaN                         Better
# 25   0.828        NaN                 About the same
# 26    0.11        NaN                          Worse
# 27     416        NaN                Unweighted base
# 28   0.077        NaN                         Better
# 29   0.819        NaN                 About the same
# ..     ...        ...                            ...
# 109  0.115        NaN                          Worse
# 110    322        NaN                Unweighted base
# 111  0.081        NaN                         Better
# 112   0.82        NaN                 About the same
# 113  0.099        NaN                          Worse
# 114    559        NaN                Unweighted base
# 115  0.076        NaN                         Better
# 116  0.792        NaN                 About the same
# 117  0.132        NaN                          Worse
# 118    230        NaN                Unweighted base
# 119  0.069        NaN                         Better
# 120  0.834        NaN                 About the same
# 121  0.098        NaN                          Worse
# 122    651        NaN                Unweighted base
# 123  0.089        NaN                         Better
# 124  0.781        NaN                 About the same
# 125  0.131        NaN                          Worse
# 126    257        NaN                Unweighted base
# 127  0.098        NaN                         Better
# 128  0.778        NaN                 About the same
# 129  0.124        NaN                          Worse
# 130    304        NaN                Unweighted base
# 131  0.094        NaN                         Better
# 132  0.778        NaN                 About the same
# 133  0.129        NaN                          Worse
# 134    561        NaN                Unweighted base
# 135  0.032        NaN                         Better
# 136  0.897        NaN                 About the same
# 137  0.071        NaN                          Worse
# 138    320        NaN                Unweighted base
#
#                                      Category                      Sect  \
# 0                                        None                All adults
# 1                                        None                All adults
# 2                                        None                All adults
# 3                                        None                All adults
# 4    Age of household reference person (HRP)1                     16-24
# 5    Age of household reference person (HRP)1                     16-24
# 6    Age of household reference person (HRP)1                     16-24
# 7    Age of household reference person (HRP)1                     16-24
# 8    Age of household reference person (HRP)1                     25-34
# 9    Age of household reference person (HRP)1                     25-34
# 10   Age of household reference person (HRP)1                     25-34
# 11   Age of household reference person (HRP)1                     25-34
# 12   Age of household reference person (HRP)1                     35-49
# 13   Age of household reference person (HRP)1                     35-49
# 14   Age of household reference person (HRP)1                     35-49
# 15   Age of household reference person (HRP)1                     35-49
# 16   Age of household reference person (HRP)1                     50-64
# 17   Age of household reference person (HRP)1                     50-64
# 18   Age of household reference person (HRP)1                     50-64
# 19   Age of household reference person (HRP)1                     50-64
# 20   Age of household reference person (HRP)1               65 and over
# 21   Age of household reference person (HRP)1               65 and over
# 22   Age of household reference person (HRP)1               65 and over
# 23   Age of household reference person (HRP)1               65 and over
# 24                                     Gender                      Male
# 25                                     Gender                      Male
# 26                                     Gender                      Male
# 27                                     Gender                      Male
# 28                                     Gender                    Female
# 29                                     Gender                    Female
# ..                                        ...                       ...
# 109                                Dependants            Has dependants
# 110                                Dependants            Has dependants
# 111                                Dependants             No dependants
# 112                                Dependants             No dependants
# 113                                Dependants             No dependants
# 114                                Dependants             No dependants
# 115                      Disability / illness  Has disability / illness
# 116                      Disability / illness  Has disability / illness
# 117                      Disability / illness  Has disability / illness
# 118                      Disability / illness  Has disability / illness
# 119                      Disability / illness   No disability / illness
# 120                      Disability / illness   No disability / illness
# 121                      Disability / illness   No disability / illness
# 122                      Disability / illness   No disability / illness
# 123                                 Area type                   Belfast
# 124                                 Area type                   Belfast
# 125                                 Area type                   Belfast
# 126                                 Area type                   Belfast
# 127                                 Area type  Urban, excluding Belfast
# 128                                 Area type  Urban, excluding Belfast
# 129                                 Area type  Urban, excluding Belfast
# 130                                 Area type  Urban, excluding Belfast
# 131                                 Area type                 All urban
# 132                                 Area type                 All urban
# 133                                 Area type                 All urban
# 134                                 Area type                 All urban
# 135                                 Area type                     Rural
# 136                                 Area type                     Rural
# 137                                 Area type                     Rural
# 138                                 Area type                     Rural
#
#     Measure Type    Unit
# 0        Percent  People
# 1        Percent  People
# 2        Percent  People
# 3        Percent  People
# 4        Percent  People
# 5        Percent  People
# 6        Percent  People
# 7        Percent  People
# 8        Percent  People
# 9        Percent  People
# 10       Percent  People
# 11       Percent  People
# 12       Percent  People
# 13       Percent  People
# 14       Percent  People
# 15       Percent  People
# 16       Percent  People
# 17       Percent  People
# 18       Percent  People
# 19       Percent  People
# 20       Percent  People
# 21       Percent  People
# 22       Percent  People
# 23       Percent  People
# 24       Percent  People
# 25       Percent  People
# 26       Percent  People
# 27       Percent  People
# 28       Percent  People
# 29       Percent  People
# ..           ...     ...
# 109      Percent  People
# 110      Percent  People
# 111      Percent  People
# 112      Percent  People
# 113      Percent  People
# 114      Percent  People
# 115      Percent  People
# 116      Percent  People
# 117      Percent  People
# 118      Percent  People
# 119      Percent  People
# 120      Percent  People
# 121      Percent  People
# 122      Percent  People
# 123      Percent  People
# 124      Percent  People
# 125      Percent  People
# 126      Percent  People
# 127      Percent  People
# 128      Percent  People
# 129      Percent  People
# 130      Percent  People
# 131      Percent  People
# 132      Percent  People
# 133      Percent  People
# 134      Percent  People
# 135      Percent  People
# 136      Percent  People
# 137      Percent  People
# 138      Percent  People
#
# [139 rows x 7 columns]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Value'] = pd.to_numeric(new_table['Value'], errors='coerce')

# %%
new_table = new_table[new_table['Value'].notnull()]

# %%
new_table['Value'] = new_table['Value'].apply(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def user_perc(x,y):
    
    if str(x) == 'Unweighted base':
        return 'Count'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Alcohol related issue response'],row['Measure Type']), axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table['Category'] = new_table['Category'].str.rstrip('1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Demographic1'] = new_table['Category'].fillna('') + ' - ' + new_table['Sect'].fillna('')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Demographic1'] = new_table['Demographic1'].str.lstrip(' - ')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table = new_table[['Demographic1','Alcohol related issue response','Measure Type','Value','Unit']]

# %%
new_table.head(5)
# Out:
#                                       Demographic1  \
# 0                                       All adults
# 1                                       All adults
# 2                                       All adults
# 3                                       All adults
# 7  Age of household reference person (HRP) - 16-24
#
#   Alcohol related issue response Measure Type  Value    Unit
# 0                         Better      Percent   0.07  People
# 1                 About the same      Percent  0.824  People
# 2                          Worse      Percent  0.106  People
# 3                Unweighted base        Count  881.0  People
# 7                Unweighted base        Count   57.0  People

# %%
import urllib.request as request
import csv
r = request.urlopen('https://raw.githubusercontent.com/ONS-OpenData/ref_alcohol/master/codelists/demographic.csv').read().decode('utf8').split("\n")
reader = csv.reader(r)
for line in reader:
    print(line)
# Out:
# ['Label', 'Notation', 'Parent Notation', 'Sort Priority']
# ['All adults', 'all-adults', '', '1']
# ['Age of household reference person (HRP) - 16-24', 'hrp/16-24', '', '2']
# ['Age of household reference person (HRP) - 25-34', 'hrp/25-34', '', '3']
# ['Age of household reference person (HRP) - 35-49', 'hrp/35-49', '', '4']
# ['Age of household reference person (HRP) - 50-64', 'hrp/50-64', '', '5']
# ['Age of household reference person (HRP) - 65 and over', 'hrp/65plus', '', '6']
# ['Gender - Male', 'male', '', '7']
# ['Gender - Female', 'female', '', '8']
# ['Religion - Catholic', 'catholic', '', '9']
# ['Religion - Protestant', 'protestant', '', '10']
# ['Religion - Other', 'other', '', '11']
# ['Health and Social Care Trust - Belfast', 'hsct/belfast', '', '12']
# ['Health and Social Care Trust - Northern', 'hsct/northern', '', '13']
# ['Health and Social Care Trust - South Eastern', 'hsct/south-eastern', '', '14']
# ['Health and Social Care Trust - Southern', 'hsct/southern', '', '15']
# ['Health and Social Care Trust - Western', 'hsct/western', '', '16']
# ['Employment status - In paid employment', 'paid-employment', '', '17']
# ['Employment status - Not in paid employment', 'not-in-paid-employment', '', '18']
# ['Marital status - Single, that is never married', 'single', '', '19']
# ['Marital status - Married and living with husband / wife', 'married', '', '20']
# ['Marital status - Married and separated from husband / wife', 'married-separated', '', '21']
# ['Marital status - Divorced', 'divorced', '', '22']
# ['Marital status - Widowed', 'widowed', '', '23']
# ['Level of qualifications - Primary', 'primary', '', '24']
# ['Level of qualifications - Secondary', 'secondary', '', '25']
# ['Level of qualifications - Tertiary', 'tertiary', '', '26']
# ['Dependants - Has dependants', 'dependants', '', '27']
# ['Dependants - No dependants', 'no-dependants', '', '28']
# ['Disability / illness - Has disability / illness', 'disability', '', '29']
# ['Disability / illness - No disability / illness', 'no-disability', '', '30']
# ['Area type - Belfast', 'belfast', '', '31']
# ['Area type - Urban, excluding Belfast', 'urban-excl-belfast', '', '32']
# ['Area type - All urban', 'all-urban', '', '33']
# ['Area type - Rural', 'rural', '', '34']

# %%
import io
import requests
url="https://raw.githubusercontent.com/ONS-OpenData/ref_alcohol/master/codelists/demographic.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
Final_table = pd.merge(new_table, c, how = 'left', left_on = 'Demographic1', right_on = 'Label')

# %%
Final_table.columns = ['Demographic' if x=='Notation' else x for x in Final_table.columns]

# %%
Final_table['Alcohol related issue response'] = Final_table['Alcohol related issue response'].map(
    lambda x: {
        'Better' : 'better', 
        'About the same' : 'same',
        'Worse': 'worse' ,
        'Unweighted base': 'unweighted-base'
        }.get(x, x))

# %%
Final_table = Final_table[Final_table['Alcohol related issue response'].notnull()]

# %%
Final_table = Final_table[['Demographic','Alcohol related issue response','Measure Type','Value','Unit']]

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

Final_table.to_csv(destinationFolder / ('table3.csv'), index = False)

# %%
Final_table['Alcohol related issue response'].unique()
# Out:
# array(['better', 'same', 'worse', 'unweighted-base'], dtype=object)
