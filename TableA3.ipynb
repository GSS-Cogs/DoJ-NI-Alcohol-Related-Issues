# %% [markdown]
# Table A3: Perceptions of change in the level of alcohol related issues in the local area in the last 12 months by demographics (%)

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
inputFile = sourceFolder / 'ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Table A3')[0]
# Out:
# Loading in\ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx which has size 191159 bytes
# Table names: ['Table A3']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<C24 0.763>, <B32 0.075>, <C16 0.819>, <C35 0.755>, <E5 881.0>, <C15 0.828>, <C39 0.887>, <C8 'n<100'>, <B37 'n<100'>, <B28 0.094>, <E26 187.0>, <D21 'n<100'>, <C25 0.871>, <D52 0.098>, <C19 0.791>, <C28 0.745>, <C9 'n<100'>, <C21 'n<100'>, <E12 260.0>, <E57 561.0>, <B43 0.087>, <C37 'n<100'>, <E42 238.0>, <B8 'n<100'>, <E10 230.0>, <Q36 'Total'>, <B12 0.071>, <D36 0.089>, <B24 0.115>, <E16 465.0>, <E32 446.0>, <B44 0.053>, <B57 0.094>, <E43 365.0>, <B47 0.055>, <E39 100.0>, <E25 238.0>, <B58 0.032>, <D27 0.063>, <D12 0.093>, <C43 0.792>, <B10 0.06>, <C20 0.85>, <B55 0.089>, <D42 0.09>, <B56 0.098>, <C47 0.83>, <E37 40.0>, <C42 0.847>, <B35 0.093>, <E48 559.0>, <E15 416.0>, <B19 0.072>, <D16 0.104>, <E11 244.0>, <C27 0.891>, <E27 165.0>, <B39 0.065>, <C57 0.778>, <D20 0.088>, <B31 0.062>, <D57 0.129>, <D51 0.132>, <D43 0.121>, <E28 144.0>, <D37 'n<100'>, <D28 0.161>, <B9 'n<100'>, <E51 230.0>, <D26 0.113>, <C11 0.854>, <B42 0.063>, <D44 0.096>, <E44 278.0>, <D48 0.099>, <B15 0.063>, <B5 0.07>, <C10 0.832>, <E38 85.0>, <E21 13.0>, <D31 0.081>, <B38 'n<100'>, <D25 0.085>, <B27 0.046>, <E55 257.0>, <B16 0.077>, <Q42 1.0>, <E24 147.0>, <B20 0.062>, <D55 0.131>, <E8 57.0>, <C58 0.897>, <C52 0.834>, <D56 0.124>, <B21 'n<100'>, <D11 0.091>, <C44 0.851>, <E9 90.0>, <D39 0.048>, <C38 'n<100'>, <D35 0.152>, <D58 0.071>, <E31 416.0>, <D10 0.108>, <D47 0.115>, <B51 0.076>, <C36 0.857>, <E52 651.0>, <D32 0.118>, <B11 0.055>, <D19 0.136>, <E36 408.0>, <E19 337.0>, <B26 0.073>, <D5 0.106>, <C32 0.807>, <C31 0.857>, <B52 0.069>, <C56 0.778>, <C26 0.814>, <C55 0.781>, <C48 0.82>, <C12 0.836>, <Q25 'Total'>, <E58 320.0>, <E20 428.0>, <E56 304.0>, <B25 0.044>, <D15 0.11>, <D9 'n<100'>, <B48 0.081>, <C51 0.792>, <C5 0.824>, <B36 0.054>, <D24 0.122>, <E47 322.0>, <E35 248.0>, <D38 'n<100'>, <D8 'n<100'>}

# %%
Alcoholissue = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Alcoholissue
# Out:
# {<E3 'Unweighted base'>, <C3 'About the same'>, <B3 'Better'>, <D3 'Worse'>}

# %%
sect = tab.excel_ref('A5').expand(DOWN).is_not_blank()
sect
# Out:
# {<A50 'Disability / illness'>, <A14 'Gender'>, <A46 'Dependants'>, <A44 'Tertiary'>, <A20 'Protestant'>, <A41 'Level of qualifications'>, <A28 'Western'>, <A24 'Belfast'>, <A10 '35-49'>, <A18 'Religion'>, <A48 'No dependants'>, <A21 'Other'>, <A30 'Employment status'>, <A62 '1. Results exclude "don\'t know" and refusals.'>, <A54 'Area type'>, <A32 'Not in paid employment'>, <A52 'No disability / illness'>, <A34 'Marital status'>, <A8 '16-24'>, <A58 'Rural'>, <A37 'Married and separated from husband / wife'>, <A57 'All urban'>, <A11 '50-64'>, <A5 'All adults'>, <A23 'Health and Social Care Trust'>, <A25 'Northern'>, <A19 'Catholic'>, <A7 'Age of household reference person (HRP)1'>, <A9 '25-34'>, <A35 'Single, that is never married'>, <A15 'Male'>, <A38 'Divorced'>, <A12 '65 and over'>, <A47 'Has dependants'>, <A61 'Source: Northern Ireland Omnibus Survey, October 2016'>, <A51 'Has disability / illness'>, <A27 'Southern'>, <A26 'South Eastern'>, <A55 'Belfast'>, <A31 'In paid employment'>, <A39 'Widowed'>, <A36 'Married and living with husband / wife'>, <A56 'Urban, excluding Belfast'>, <A16 'Female'>, <A42 'Primary'>, <A43 'Secondary'>}

# %%
category = tab.excel_ref('A').expand(DOWN).by_index([7,14,18,23,30,34,41,46,50,54])
category
# Out:
# {<A50 'Disability / illness'>, <A14 'Gender'>, <A46 'Dependants'>, <A54 'Area type'>, <A41 'Level of qualifications'>, <A23 'Health and Social Care Trust'>, <A34 'Marital status'>, <A7 'Age of household reference person (HRP)1'>, <A18 'Religion'>, <A30 'Employment status'>}

# %%
Dimensions = [
            HDim(Alcoholissue,'Alcohol issue',DIRECTLY,ABOVE),
            HDim(category,'Category',CLOSEST,ABOVE),
            HDim(sect,'Sect',DIRECTLY,LEFT),
            HDimConst('Measure Type', 'Percentage'),
            HDimConst('Unit','People'),
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS DATAMARKER    Alcohol issue  \
# 0     0.07        NaN           Better
# 1    0.824        NaN   About the same
# 2    0.106        NaN            Worse
# 3      881        NaN  Unweighted base
# 4               n<100           Better
# 5               n<100   About the same
# 6               n<100            Worse
# 7       57        NaN  Unweighted base
# 8               n<100           Better
# 9               n<100   About the same
# 10              n<100            Worse
# 11      90        NaN  Unweighted base
# 12    0.06        NaN           Better
# 13   0.832        NaN   About the same
# 14   0.108        NaN            Worse
# 15     230        NaN  Unweighted base
# 16   0.055        NaN           Better
# 17   0.854        NaN   About the same
# 18   0.091        NaN            Worse
# 19     244        NaN  Unweighted base
# 20   0.071        NaN           Better
# 21   0.836        NaN   About the same
# 22   0.093        NaN            Worse
# 23     260        NaN  Unweighted base
# 24   0.063        NaN           Better
# 25   0.828        NaN   About the same
# 26    0.11        NaN            Worse
# 27     416        NaN  Unweighted base
# 28   0.077        NaN           Better
# 29   0.819        NaN   About the same
# ..     ...        ...              ...
# 109  0.115        NaN            Worse
# 110    322        NaN  Unweighted base
# 111  0.081        NaN           Better
# 112   0.82        NaN   About the same
# 113  0.099        NaN            Worse
# 114    559        NaN  Unweighted base
# 115  0.076        NaN           Better
# 116  0.792        NaN   About the same
# 117  0.132        NaN            Worse
# 118    230        NaN  Unweighted base
# 119  0.069        NaN           Better
# 120  0.834        NaN   About the same
# 121  0.098        NaN            Worse
# 122    651        NaN  Unweighted base
# 123  0.089        NaN           Better
# 124  0.781        NaN   About the same
# 125  0.131        NaN            Worse
# 126    257        NaN  Unweighted base
# 127  0.098        NaN           Better
# 128  0.778        NaN   About the same
# 129  0.124        NaN            Worse
# 130    304        NaN  Unweighted base
# 131  0.094        NaN           Better
# 132  0.778        NaN   About the same
# 133  0.129        NaN            Worse
# 134    561        NaN  Unweighted base
# 135  0.032        NaN           Better
# 136  0.897        NaN   About the same
# 137  0.071        NaN            Worse
# 138    320        NaN  Unweighted base
#
#                                      Category                      Sect  \
# 0                                        None                All adults
# 1                                        None                All adults
# 2                                        None                All adults
# 3                                        None                All adults
# 4    Age of household reference person (HRP)1                     16-24
# 5    Age of household reference person (HRP)1                     16-24
# 6    Age of household reference person (HRP)1                     16-24
# 7    Age of household reference person (HRP)1                     16-24
# 8    Age of household reference person (HRP)1                     25-34
# 9    Age of household reference person (HRP)1                     25-34
# 10   Age of household reference person (HRP)1                     25-34
# 11   Age of household reference person (HRP)1                     25-34
# 12   Age of household reference person (HRP)1                     35-49
# 13   Age of household reference person (HRP)1                     35-49
# 14   Age of household reference person (HRP)1                     35-49
# 15   Age of household reference person (HRP)1                     35-49
# 16   Age of household reference person (HRP)1                     50-64
# 17   Age of household reference person (HRP)1                     50-64
# 18   Age of household reference person (HRP)1                     50-64
# 19   Age of household reference person (HRP)1                     50-64
# 20   Age of household reference person (HRP)1               65 and over
# 21   Age of household reference person (HRP)1               65 and over
# 22   Age of household reference person (HRP)1               65 and over
# 23   Age of household reference person (HRP)1               65 and over
# 24                                     Gender                      Male
# 25                                     Gender                      Male
# 26                                     Gender                      Male
# 27                                     Gender                      Male
# 28                                     Gender                    Female
# 29                                     Gender                    Female
# ..                                        ...                       ...
# 109                                Dependants            Has dependants
# 110                                Dependants            Has dependants
# 111                                Dependants             No dependants
# 112                                Dependants             No dependants
# 113                                Dependants             No dependants
# 114                                Dependants             No dependants
# 115                      Disability / illness  Has disability / illness
# 116                      Disability / illness  Has disability / illness
# 117                      Disability / illness  Has disability / illness
# 118                      Disability / illness  Has disability / illness
# 119                      Disability / illness   No disability / illness
# 120                      Disability / illness   No disability / illness
# 121                      Disability / illness   No disability / illness
# 122                      Disability / illness   No disability / illness
# 123                                 Area type                   Belfast
# 124                                 Area type                   Belfast
# 125                                 Area type                   Belfast
# 126                                 Area type                   Belfast
# 127                                 Area type  Urban, excluding Belfast
# 128                                 Area type  Urban, excluding Belfast
# 129                                 Area type  Urban, excluding Belfast
# 130                                 Area type  Urban, excluding Belfast
# 131                                 Area type                 All urban
# 132                                 Area type                 All urban
# 133                                 Area type                 All urban
# 134                                 Area type                 All urban
# 135                                 Area type                     Rural
# 136                                 Area type                     Rural
# 137                                 Area type                     Rural
# 138                                 Area type                     Rural
#
#     Measure Type    Unit
# 0     Percentage  People
# 1     Percentage  People
# 2     Percentage  People
# 3     Percentage  People
# 4     Percentage  People
# 5     Percentage  People
# 6     Percentage  People
# 7     Percentage  People
# 8     Percentage  People
# 9     Percentage  People
# 10    Percentage  People
# 11    Percentage  People
# 12    Percentage  People
# 13    Percentage  People
# 14    Percentage  People
# 15    Percentage  People
# 16    Percentage  People
# 17    Percentage  People
# 18    Percentage  People
# 19    Percentage  People
# 20    Percentage  People
# 21    Percentage  People
# 22    Percentage  People
# 23    Percentage  People
# 24    Percentage  People
# 25    Percentage  People
# 26    Percentage  People
# 27    Percentage  People
# 28    Percentage  People
# 29    Percentage  People
# ..           ...     ...
# 109   Percentage  People
# 110   Percentage  People
# 111   Percentage  People
# 112   Percentage  People
# 113   Percentage  People
# 114   Percentage  People
# 115   Percentage  People
# 116   Percentage  People
# 117   Percentage  People
# 118   Percentage  People
# 119   Percentage  People
# 120   Percentage  People
# 121   Percentage  People
# 122   Percentage  People
# 123   Percentage  People
# 124   Percentage  People
# 125   Percentage  People
# 126   Percentage  People
# 127   Percentage  People
# 128   Percentage  People
# 129   Percentage  People
# 130   Percentage  People
# 131   Percentage  People
# 132   Percentage  People
# 133   Percentage  People
# 134   Percentage  People
# 135   Percentage  People
# 136   Percentage  People
# 137   Percentage  People
# 138   Percentage  People
#
# [139 rows x 7 columns]

# %%
new_table.columns = ['Response' if x=='OBS' else x for x in new_table.columns]

# %%
new_table = new_table[new_table['Response'] != ' ']

# %%
new_table.dtypes
# Out:
# Response         object
# DATAMARKER       object
# Alcohol issue    object
# Category         object
# Sect             object
# Measure Type     object
# Unit             object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Response DATAMARKER    Alcohol issue   Category       Sect Measure Type  \
# 134      561        NaN  Unweighted base  Area type  All urban   Percentage
# 135    0.032        NaN           Better  Area type      Rural   Percentage
# 136    0.897        NaN   About the same  Area type      Rural   Percentage
# 137    0.071        NaN            Worse  Area type      Rural   Percentage
# 138      320        NaN  Unweighted base  Area type      Rural   Percentage
#
#        Unit
# 134  People
# 135  People
# 136  People
# 137  People
# 138  People

# %%
new_table.head()
# Out:
#   Response DATAMARKER    Alcohol issue  \
# 0     0.07        NaN           Better
# 1    0.824        NaN   About the same
# 2    0.106        NaN            Worse
# 3      881        NaN  Unweighted base
# 4               n<100           Better
#
#                                    Category        Sect Measure Type    Unit
# 0                                      None  All adults   Percentage  People
# 1                                      None  All adults   Percentage  People
# 2                                      None  All adults   Percentage  People
# 3                                      None  All adults   Percentage  People
# 4  Age of household reference person (HRP)1       16-24   Percentage  People

# %%
new_table['Response'] = pd.to_numeric(new_table['Response'], errors='coerce')

# %%
new_table['Response'] = new_table['Response'].apply(str)

# %%
def user_perc(x,y):
    
    if str(x) == 'Unweighted base':
        return 'Number'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Alcohol issue'],row['Measure Type']), axis = 1)

# %%
new_table['Category'].fillna('All', inplace = True)

# %%
new_table['Demographic'] = new_table['Category'] + '/' + new_table['Sect']

# %%
new_table = new_table[['Demographic','Alcohol issue','Measure Type','Response','Unit']]

# %%
new_table.head(5)
# Out:
#                                       Demographic    Alcohol issue  \
# 0                                  All/All adults           Better
# 1                                  All/All adults   About the same
# 2                                  All/All adults            Worse
# 3                                  All/All adults  Unweighted base
# 4  Age of household reference person (HRP)1/16-24           Better
#
#   Measure Type Response    Unit
# 0   Percentage     0.07  People
# 1   Percentage    0.824  People
# 2   Percentage    0.106  People
# 3       Number    881.0  People
# 4   Percentage      nan  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('taba3.csv'), index = False)
