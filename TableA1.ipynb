# %% [markdown]
# Table A1: Concern about alcohol related issues in the local area by demographics (%)

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
inputFile = sourceFolder / 'ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Table A1')[0]
# Out:
# Loading in\ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx which has size 191159 bytes
# Table names: ['Table A1']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<E11 259.0>, <D15 0.382>, <C19 0.133>, <D27 0.44>, <D9 0.521>, <D35 0.415>, <E58 339.0>, <D10 0.373>, <D11 0.368>, <C26 0.161>, <D58 0.486>, <E9 100.0>, <D48 0.42>, <D55 0.42>, <C37 'n<100'>, <E35 271.0>, <B8 'n<100'>, <D56 0.294>, <C5 0.164>, <B15 0.458>, <D39 0.493>, <E8 66.0>, <E20 454.0>, <B27 0.399>, <B28 0.551>, <B25 0.405>, <C32 0.138>, <B9 0.313>, <C43 0.164>, <E27 181.0>, <E26 195.0>, <E28 152.0>, <B58 0.304>, <B51 0.5>, <D8 'n<100'>, <D32 0.378>, <D44 0.428>, <D24 0.442>, <D5 0.403>, <E32 479.0>, <C51 0.096>, <C15 0.16>, <B21 'n<100'>, <C36 0.172>, <E37 46.0>, <C57 0.136>, <D37 'n<100'>, <B19 0.471>, <C31 0.197>, <B5 0.433>, <C8 'n<100'>, <B37 'n<100'>, <E19 360.0>, <C52 0.183>, <D21 'n<100'>, <B57 0.514>, <B32 0.484>, <B52 0.414>, <D25 0.409>, <C58 0.21>, <C21 'n<100'>, <D26 0.414>, <C48 0.156>, <E12 272.0>, <E51 243.0>, <D28 0.295>, <C55 0.16>, <E25 251.0>, <D57 0.351>, <D19 0.396>, <E38 87.0>, <C28 0.154>, <E56 325.0>, <C27 0.161>, <C10 0.217>, <C38 'n<100'>, <D42 0.417>, <E31 446.0>, <E5 945.0>, <B16 0.412>, <B24 0.415>, <B12 0.438>, <E48 602.0>, <E10 248.0>, <B56 0.589>, <E24 166.0>, <B44 0.366>, <E47 343.0>, <C20 0.183>, <B35 0.407>, <D16 0.42>, <E36 433.0>, <D36 0.384>, <C44 0.206>, <B38 'n<100'>, <B10 0.41>, <E16 510.0>, <C16 0.168>, <D20 0.411>, <D47 0.377>, <E15 435.0>, <E55 281.0>, <C24 0.143>, <C56 0.117>, <C42 0.112>, <E42 259.0>, <E43 382.0>, <C9 0.167>, <C35 0.178>, <C12 0.146>, <D43 0.373>, <B42 0.471>, <D51 0.404>, <D52 0.403>, <E39 108.0>, <C47 0.176>, <E44 304.0>, <B36 0.444>, <B26 0.425>, <D38 'n<100'>, <B11 0.491>, <E21 16.0>, <E57 606.0>, <B47 0.447>, <B20 0.406>, <D12 0.416>, <B48 0.424>, <C39 0.119>, <B55 0.42>, <C25 0.186>, <E52 702.0>, <B31 0.379>, <B43 0.463>, <B39 0.388>, <D31 0.424>, <C11 0.141>}

# %%
Alcoholissue = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Alcoholissue
# Out:
# {<C3 'Neither agree nor disagree'>, <D3 'Disagree / strongly disagree'>, <E3 'Unweighted base'>, <B3 'Agree / strongly agree'>}

# %%
sect = tab.excel_ref('A5').expand(DOWN).is_not_blank()
sect
# Out:
# {<A46 'Dependants'>, <A19 'Catholic'>, <A56 'Urban, excluding Belfast'>, <A16 'Female'>, <A57 'All urban'>, <A52 'No disability / illness'>, <A54 'Area type'>, <A55 'Belfast'>, <A8 '16-24'>, <A39 'Widowed'>, <A30 'Employment status'>, <A12 '65 and over'>, <A62 '1. Results exclude "don\'t know" and refusals.'>, <A23 'Health and Social Care Trust'>, <A32 'Not in paid employment'>, <A48 'No dependants'>, <A61 'Source: Northern Ireland Omnibus Survey, October 2016'>, <A28 'Western'>, <A41 'Level of qualifications'>, <A58 'Rural'>, <A20 'Protestant'>, <A50 'Disability / illness'>, <A5 'All adults'>, <A7 'Age of household reference person (HRP)1'>, <A37 'Married and separated from husband / wife'>, <A25 'Northern'>, <A34 'Marital status'>, <A9 '25-34'>, <A42 'Primary'>, <A11 '50-64'>, <A43 'Secondary'>, <A18 'Religion'>, <A27 'Southern'>, <A36 'Married and living with husband / wife'>, <A15 'Male'>, <A35 'Single, that is never married'>, <A10 '35-49'>, <A44 'Tertiary'>, <A38 'Divorced'>, <A24 'Belfast'>, <A21 'Other'>, <A26 'South Eastern'>, <A14 'Gender'>, <A51 'Has disability / illness'>, <A31 'In paid employment'>, <A47 'Has dependants'>}

# %%
category = tab.excel_ref('A').expand(DOWN).by_index([7,14,18,23,30,34,41,46,50,54])
category
# Out:
# {<A46 'Dependants'>, <A34 'Marital status'>, <A23 'Health and Social Care Trust'>, <A54 'Area type'>, <A18 'Religion'>, <A41 'Level of qualifications'>, <A14 'Gender'>, <A50 'Disability / illness'>, <A30 'Employment status'>, <A7 'Age of household reference person (HRP)1'>}

# %%
Dimensions = [
            HDim(Alcoholissue,'Alcohol issue',DIRECTLY,ABOVE),
            HDim(category,'Category',CLOSEST,ABOVE),
            HDim(sect,'Sect',DIRECTLY,LEFT),
            HDimConst('Measure Type', 'Percentage'),
            HDimConst('Unit','People'),
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS DATAMARKER                 Alcohol issue  \
# 0    0.433        NaN        Agree / strongly agree
# 1    0.164        NaN    Neither agree nor disagree
# 2    0.403        NaN  Disagree / strongly disagree
# 3      945        NaN               Unweighted base
# 4               n<100        Agree / strongly agree
# 5               n<100    Neither agree nor disagree
# 6               n<100  Disagree / strongly disagree
# 7       66        NaN               Unweighted base
# 8    0.313        NaN        Agree / strongly agree
# 9    0.167        NaN    Neither agree nor disagree
# 10   0.521        NaN  Disagree / strongly disagree
# 11     100        NaN               Unweighted base
# 12    0.41        NaN        Agree / strongly agree
# 13   0.217        NaN    Neither agree nor disagree
# 14   0.373        NaN  Disagree / strongly disagree
# 15     248        NaN               Unweighted base
# 16   0.491        NaN        Agree / strongly agree
# 17   0.141        NaN    Neither agree nor disagree
# 18   0.368        NaN  Disagree / strongly disagree
# 19     259        NaN               Unweighted base
# 20   0.438        NaN        Agree / strongly agree
# 21   0.146        NaN    Neither agree nor disagree
# 22   0.416        NaN  Disagree / strongly disagree
# 23     272        NaN               Unweighted base
# 24   0.458        NaN        Agree / strongly agree
# 25    0.16        NaN    Neither agree nor disagree
# 26   0.382        NaN  Disagree / strongly disagree
# 27     435        NaN               Unweighted base
# 28   0.412        NaN        Agree / strongly agree
# 29   0.168        NaN    Neither agree nor disagree
# ..     ...        ...                           ...
# 106  0.377        NaN  Disagree / strongly disagree
# 107    343        NaN               Unweighted base
# 108  0.424        NaN        Agree / strongly agree
# 109  0.156        NaN    Neither agree nor disagree
# 110   0.42        NaN  Disagree / strongly disagree
# 111    602        NaN               Unweighted base
# 112    0.5        NaN        Agree / strongly agree
# 113  0.096        NaN    Neither agree nor disagree
# 114  0.404        NaN  Disagree / strongly disagree
# 115    243        NaN               Unweighted base
# 116  0.414        NaN        Agree / strongly agree
# 117  0.183        NaN    Neither agree nor disagree
# 118  0.403        NaN  Disagree / strongly disagree
# 119    702        NaN               Unweighted base
# 120   0.42        NaN        Agree / strongly agree
# 121   0.16        NaN    Neither agree nor disagree
# 122   0.42        NaN  Disagree / strongly disagree
# 123    281        NaN               Unweighted base
# 124  0.589        NaN        Agree / strongly agree
# 125  0.117        NaN    Neither agree nor disagree
# 126  0.294        NaN  Disagree / strongly disagree
# 127    325        NaN               Unweighted base
# 128  0.514        NaN        Agree / strongly agree
# 129  0.136        NaN    Neither agree nor disagree
# 130  0.351        NaN  Disagree / strongly disagree
# 131    606        NaN               Unweighted base
# 132  0.304        NaN        Agree / strongly agree
# 133   0.21        NaN    Neither agree nor disagree
# 134  0.486        NaN  Disagree / strongly disagree
# 135    339        NaN               Unweighted base
#
#                                      Category                      Sect  \
# 0                                        None                All adults
# 1                                        None                All adults
# 2                                        None                All adults
# 3                                        None                All adults
# 4    Age of household reference person (HRP)1                     16-24
# 5    Age of household reference person (HRP)1                     16-24
# 6    Age of household reference person (HRP)1                     16-24
# 7    Age of household reference person (HRP)1                     16-24
# 8    Age of household reference person (HRP)1                     25-34
# 9    Age of household reference person (HRP)1                     25-34
# 10   Age of household reference person (HRP)1                     25-34
# 11   Age of household reference person (HRP)1                     25-34
# 12   Age of household reference person (HRP)1                     35-49
# 13   Age of household reference person (HRP)1                     35-49
# 14   Age of household reference person (HRP)1                     35-49
# 15   Age of household reference person (HRP)1                     35-49
# 16   Age of household reference person (HRP)1                     50-64
# 17   Age of household reference person (HRP)1                     50-64
# 18   Age of household reference person (HRP)1                     50-64
# 19   Age of household reference person (HRP)1                     50-64
# 20   Age of household reference person (HRP)1               65 and over
# 21   Age of household reference person (HRP)1               65 and over
# 22   Age of household reference person (HRP)1               65 and over
# 23   Age of household reference person (HRP)1               65 and over
# 24                                     Gender                      Male
# 25                                     Gender                      Male
# 26                                     Gender                      Male
# 27                                     Gender                      Male
# 28                                     Gender                    Female
# 29                                     Gender                    Female
# ..                                        ...                       ...
# 106                                Dependants            Has dependants
# 107                                Dependants            Has dependants
# 108                                Dependants             No dependants
# 109                                Dependants             No dependants
# 110                                Dependants             No dependants
# 111                                Dependants             No dependants
# 112                      Disability / illness  Has disability / illness
# 113                      Disability / illness  Has disability / illness
# 114                      Disability / illness  Has disability / illness
# 115                      Disability / illness  Has disability / illness
# 116                      Disability / illness   No disability / illness
# 117                      Disability / illness   No disability / illness
# 118                      Disability / illness   No disability / illness
# 119                      Disability / illness   No disability / illness
# 120                                 Area type                   Belfast
# 121                                 Area type                   Belfast
# 122                                 Area type                   Belfast
# 123                                 Area type                   Belfast
# 124                                 Area type  Urban, excluding Belfast
# 125                                 Area type  Urban, excluding Belfast
# 126                                 Area type  Urban, excluding Belfast
# 127                                 Area type  Urban, excluding Belfast
# 128                                 Area type                 All urban
# 129                                 Area type                 All urban
# 130                                 Area type                 All urban
# 131                                 Area type                 All urban
# 132                                 Area type                     Rural
# 133                                 Area type                     Rural
# 134                                 Area type                     Rural
# 135                                 Area type                     Rural
#
#     Measure Type    Unit
# 0     Percentage  People
# 1     Percentage  People
# 2     Percentage  People
# 3     Percentage  People
# 4     Percentage  People
# 5     Percentage  People
# 6     Percentage  People
# 7     Percentage  People
# 8     Percentage  People
# 9     Percentage  People
# 10    Percentage  People
# 11    Percentage  People
# 12    Percentage  People
# 13    Percentage  People
# 14    Percentage  People
# 15    Percentage  People
# 16    Percentage  People
# 17    Percentage  People
# 18    Percentage  People
# 19    Percentage  People
# 20    Percentage  People
# 21    Percentage  People
# 22    Percentage  People
# 23    Percentage  People
# 24    Percentage  People
# 25    Percentage  People
# 26    Percentage  People
# 27    Percentage  People
# 28    Percentage  People
# 29    Percentage  People
# ..           ...     ...
# 106   Percentage  People
# 107   Percentage  People
# 108   Percentage  People
# 109   Percentage  People
# 110   Percentage  People
# 111   Percentage  People
# 112   Percentage  People
# 113   Percentage  People
# 114   Percentage  People
# 115   Percentage  People
# 116   Percentage  People
# 117   Percentage  People
# 118   Percentage  People
# 119   Percentage  People
# 120   Percentage  People
# 121   Percentage  People
# 122   Percentage  People
# 123   Percentage  People
# 124   Percentage  People
# 125   Percentage  People
# 126   Percentage  People
# 127   Percentage  People
# 128   Percentage  People
# 129   Percentage  People
# 130   Percentage  People
# 131   Percentage  People
# 132   Percentage  People
# 133   Percentage  People
# 134   Percentage  People
# 135   Percentage  People
#
# [136 rows x 7 columns]

# %%
new_table.columns = ['Response' if x=='OBS' else x for x in new_table.columns]

# %%
new_table = new_table[new_table['Response'] != ' ']

# %%
new_table.dtypes
# Out:
# Response         object
# DATAMARKER       object
# Alcohol issue    object
# Category         object
# Sect             object
# Measure Type     object
# Unit             object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Response DATAMARKER                 Alcohol issue   Category       Sect  \
# 131      606        NaN               Unweighted base  Area type  All urban
# 132    0.304        NaN        Agree / strongly agree  Area type      Rural
# 133     0.21        NaN    Neither agree nor disagree  Area type      Rural
# 134    0.486        NaN  Disagree / strongly disagree  Area type      Rural
# 135      339        NaN               Unweighted base  Area type      Rural
#
#     Measure Type    Unit
# 131   Percentage  People
# 132   Percentage  People
# 133   Percentage  People
# 134   Percentage  People
# 135   Percentage  People

# %%
new_table.head()
# Out:
#   Response DATAMARKER                 Alcohol issue  \
# 0    0.433        NaN        Agree / strongly agree
# 1    0.164        NaN    Neither agree nor disagree
# 2    0.403        NaN  Disagree / strongly disagree
# 3      945        NaN               Unweighted base
# 4               n<100        Agree / strongly agree
#
#                                    Category        Sect Measure Type    Unit
# 0                                      None  All adults   Percentage  People
# 1                                      None  All adults   Percentage  People
# 2                                      None  All adults   Percentage  People
# 3                                      None  All adults   Percentage  People
# 4  Age of household reference person (HRP)1       16-24   Percentage  People

# %%
new_table['Response'] = pd.to_numeric(new_table['Response'], errors='coerce')

# %%
new_table['Response'] = new_table['Response'].apply(str)

# %%
def user_perc(x,y):
    
    if str(x) == 'Unweighted base':
        return 'Number'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Alcohol issue'],row['Measure Type']), axis = 1)

# %%
new_table['Category'].fillna('All', inplace = True)

# %%
new_table['Demographic'] = new_table['Category'] + '/' + new_table['Sect']

# %%
new_table = new_table[['Demographic','Alcohol issue','Measure Type','Response','Unit']]

# %%
new_table.head(5)
# Out:
#                                       Demographic  \
# 0                                  All/All adults
# 1                                  All/All adults
# 2                                  All/All adults
# 3                                  All/All adults
# 4  Age of household reference person (HRP)1/16-24
#
#                   Alcohol issue Measure Type Response    Unit
# 0        Agree / strongly agree   Percentage    0.433  People
# 1    Neither agree nor disagree   Percentage    0.164  People
# 2  Disagree / strongly disagree   Percentage    0.403  People
# 3               Unweighted base       Number    945.0  People
# 4        Agree / strongly agree   Percentage      nan  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('taba1.csv'), index = False)
