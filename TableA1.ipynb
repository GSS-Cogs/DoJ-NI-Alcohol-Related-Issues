# %% [markdown]
# Table A1: Concern about alcohol related issues in the local area by demographics (%)

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper(
        "https://www.justice-ni.gov.uk/publications/"
        "research-and-statistical-bulletin-82017-views-alcohol-and-drug-related-issues-findings-october-2016")
scraper
# Out:
# ## Research and Statistical Bulletin 8/2017 ‘Views on Alcohol and Drug Related Issues: Findings from the October 2016 Northern Ireland Omnibus Survey’
#
# ### Distributions
#
# 1. Bulletin 8-3028 omnibus survey views on alcohol and drug related issues: Findings from October 2016 ([application/pdf](https://www.justice-ni.gov.uk/sites/default/files/publications/justice/oct-2016-omnibus-survey-drugs-alcohol-bulletin.pdf))
# 1. October 2016 alcohol and drugs findings data table ([MS Excel Spreadsheet](https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx))
# 1. Drugs and alcohol infographics 2016 ([application/pdf](https://www.justice-ni.gov.uk/sites/default/files/publications/justice/drugs-and-alcohol-infographics-2016.pdf))

# %%
if is_interactive():
    tabs = {tab.name: tab for tab in scraper.distribution(
        title='October 2016 alcohol and drugs findings data table').as_databaker()}
tabs.keys()
# Out:
# dict_keys(['Metadata', 'Index', 'Table A1', 'Table A2', 'Table A3', 'Table A4', 'Table A5', 'Table A6', 'Table A7', 'Table A8', 'Table A9', 'Table A10', 'Table A11', 'Table A12', 'Table A13', 'Table A14', 'Table A15', 'Table A16', 'Table A17', 'Table B1', 'Table B2', 'Table B3'])

# %% [markdown]
# https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx

# %%
tab = tabs['Table A1']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<C8 'n<100'>, <C57 0.136>, <B19 0.471>, <B56 0.589>, <B5 0.433>, <C38 'n<100'>, <E19 360.0>, <E24 166.0>, <B8 'n<100'>, <B57 0.514>, <B32 0.484>, <C20 0.183>, <D16 0.42>, <D26 0.414>, <E12 272.0>, <E51 243.0>, <B10 0.41>, <E16 510.0>, <C55 0.16>, <C16 0.168>, <D47 0.377>, <C42 0.112>, <E38 87.0>, <C28 0.154>, <B42 0.471>, <D51 0.404>, <D42 0.417>, <E31 446.0>, <E5 945.0>, <E39 108.0>, <C47 0.176>, <B36 0.444>, <B26 0.425>, <B11 0.491>, <B16 0.412>, <B37 'n<100'>, <E57 606.0>, <B20 0.406>, <D12 0.416>, <B55 0.42>, <B12 0.438>, <E52 702.0>, <E48 602.0>, <E10 248.0>, <B43 0.463>, <B39 0.388>, <D31 0.424>, <C11 0.141>, <E11 259.0>, <B44 0.366>, <D15 0.382>, <E47 343.0>, <D9 0.521>, <D35 0.415>, <B35 0.407>, <C26 0.161>, <E36 433.0>, <D36 0.384>, <C44 0.206>, <D48 0.42>, <E35 271.0>, <D20 0.411>, <E15 435.0>, <C5 0.164>, <E55 281.0>, <C56 0.117>, <C24 0.143>, <B27 0.399>, <B38 'n<100'>, <E43 382.0>, <E42 259.0>, <C9 0.167>, <C35 0.178>, <D43 0.373>, <C12 0.146>, <C32 0.138>, <D52 0.403>, <E44 304.0>, <C43 0.164>, <E27 181.0>, <E28 152.0>, <E21 16.0>, <B47 0.447>, <B58 0.304>, <B48 0.424>, <C39 0.119>, <C25 0.186>, <D32 0.378>, <B31 0.379>, <D21 'n<100'>, <D44 0.428>, <D5 0.403>, <C19 0.133>, <E32 479.0>, <D27 0.44>, <D38 'n<100'>, <D8 'n<100'>, <E58 339.0>, <D10 0.373>, <D11 0.368>, <C15 0.16>, <C36 0.172>, <D58 0.486>, <E9 100.0>, <D55 0.42>, <D56 0.294>, <B15 0.458>, <E20 454.0>, <D39 0.493>, <E8 66.0>, <B28 0.551>, <B25 0.405>, <C31 0.197>, <C52 0.183>, <C21 'n<100'>, <B9 0.313>, <E26 195.0>, <C37 'n<100'>, <B52 0.414>, <D25 0.409>, <C58 0.21>, <B21 'n<100'>, <C48 0.156>, <B51 0.5>, <D28 0.295>, <D37 'n<100'>, <E25 251.0>, <D57 0.351>, <D19 0.396>, <D24 0.442>, <E56 325.0>, <C27 0.161>, <C10 0.217>, <C51 0.096>, <E37 46.0>, <B24 0.415>}

# %%
Alcoholissue = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Alcoholissue
# Out:
# {<D3 'Disagree / strongly disagree'>, <C3 'Neither agree nor disagree'>, <B3 'Agree / strongly agree'>, <E3 'Unweighted base'>}

# %%
sect = tab.excel_ref('A5').expand(DOWN).is_not_blank()
sect
# Out:
# {<A23 'Health and Social Care Trust'>, <A55 'Belfast'>, <A19 'Catholic'>, <A51 'Has disability / illness'>, <A5 'All adults'>, <A25 'Northern'>, <A58 'Rural'>, <A57 'All urban'>, <A43 'Secondary'>, <A61 'Source: Northern Ireland Omnibus Survey, October 2016'>, <A12 '65 and over'>, <A8 '16-24'>, <A37 'Married and separated from husband / wife'>, <A9 '25-34'>, <A31 'In paid employment'>, <A47 'Has dependants'>, <A7 'Age of household reference person (HRP)1'>, <A27 'Southern'>, <A34 'Marital status'>, <A16 'Female'>, <A14 'Gender'>, <A46 'Dependants'>, <A62 '1. Results exclude "don\'t know" and refusals.'>, <A42 'Primary'>, <A56 'Urban, excluding Belfast'>, <A30 'Employment status'>, <A11 '50-64'>, <A32 'Not in paid employment'>, <A28 'Western'>, <A39 'Widowed'>, <A10 '35-49'>, <A20 'Protestant'>, <A21 'Other'>, <A41 'Level of qualifications'>, <A38 'Divorced'>, <A24 'Belfast'>, <A15 'Male'>, <A35 'Single, that is never married'>, <A48 'No dependants'>, <A52 'No disability / illness'>, <A54 'Area type'>, <A50 'Disability / illness'>, <A26 'South Eastern'>, <A18 'Religion'>, <A36 'Married and living with husband / wife'>, <A44 'Tertiary'>}

# %%
category = tab.excel_ref('A').expand(DOWN).by_index([7,14,18,23,30,34,41,46,50,54])
category
# Out:
# {<A14 'Gender'>, <A23 'Health and Social Care Trust'>, <A34 'Marital status'>, <A54 'Area type'>, <A30 'Employment status'>, <A50 'Disability / illness'>, <A18 'Religion'>, <A7 'Age of household reference person (HRP)1'>, <A41 'Level of qualifications'>, <A46 'Dependants'>}

# %%
Dimensions = [
            HDim(Alcoholissue,'Alcohol related issue response',DIRECTLY,ABOVE),
            HDim(category,'Category',CLOSEST,ABOVE),
            HDim(sect,'Sect',DIRECTLY,LEFT),
            HDimConst('Measure Type', 'Percent'),
            HDimConst('Unit','People'),
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS DATAMARKER Alcohol related issue response  \
# 0    0.433        NaN         Agree / strongly agree
# 1    0.164        NaN     Neither agree nor disagree
# 2    0.403        NaN   Disagree / strongly disagree
# 3      945        NaN                Unweighted base
# 4               n<100         Agree / strongly agree
# 5               n<100     Neither agree nor disagree
# 6               n<100   Disagree / strongly disagree
# 7       66        NaN                Unweighted base
# 8    0.313        NaN         Agree / strongly agree
# 9    0.167        NaN     Neither agree nor disagree
# 10   0.521        NaN   Disagree / strongly disagree
# 11     100        NaN                Unweighted base
# 12    0.41        NaN         Agree / strongly agree
# 13   0.217        NaN     Neither agree nor disagree
# 14   0.373        NaN   Disagree / strongly disagree
# 15     248        NaN                Unweighted base
# 16   0.491        NaN         Agree / strongly agree
# 17   0.141        NaN     Neither agree nor disagree
# 18   0.368        NaN   Disagree / strongly disagree
# 19     259        NaN                Unweighted base
# 20   0.438        NaN         Agree / strongly agree
# 21   0.146        NaN     Neither agree nor disagree
# 22   0.416        NaN   Disagree / strongly disagree
# 23     272        NaN                Unweighted base
# 24   0.458        NaN         Agree / strongly agree
# 25    0.16        NaN     Neither agree nor disagree
# 26   0.382        NaN   Disagree / strongly disagree
# 27     435        NaN                Unweighted base
# 28   0.412        NaN         Agree / strongly agree
# 29   0.168        NaN     Neither agree nor disagree
# ..     ...        ...                            ...
# 106  0.377        NaN   Disagree / strongly disagree
# 107    343        NaN                Unweighted base
# 108  0.424        NaN         Agree / strongly agree
# 109  0.156        NaN     Neither agree nor disagree
# 110   0.42        NaN   Disagree / strongly disagree
# 111    602        NaN                Unweighted base
# 112    0.5        NaN         Agree / strongly agree
# 113  0.096        NaN     Neither agree nor disagree
# 114  0.404        NaN   Disagree / strongly disagree
# 115    243        NaN                Unweighted base
# 116  0.414        NaN         Agree / strongly agree
# 117  0.183        NaN     Neither agree nor disagree
# 118  0.403        NaN   Disagree / strongly disagree
# 119    702        NaN                Unweighted base
# 120   0.42        NaN         Agree / strongly agree
# 121   0.16        NaN     Neither agree nor disagree
# 122   0.42        NaN   Disagree / strongly disagree
# 123    281        NaN                Unweighted base
# 124  0.589        NaN         Agree / strongly agree
# 125  0.117        NaN     Neither agree nor disagree
# 126  0.294        NaN   Disagree / strongly disagree
# 127    325        NaN                Unweighted base
# 128  0.514        NaN         Agree / strongly agree
# 129  0.136        NaN     Neither agree nor disagree
# 130  0.351        NaN   Disagree / strongly disagree
# 131    606        NaN                Unweighted base
# 132  0.304        NaN         Agree / strongly agree
# 133   0.21        NaN     Neither agree nor disagree
# 134  0.486        NaN   Disagree / strongly disagree
# 135    339        NaN                Unweighted base
#
#                                      Category                      Sect  \
# 0                                        None                All adults
# 1                                        None                All adults
# 2                                        None                All adults
# 3                                        None                All adults
# 4    Age of household reference person (HRP)1                     16-24
# 5    Age of household reference person (HRP)1                     16-24
# 6    Age of household reference person (HRP)1                     16-24
# 7    Age of household reference person (HRP)1                     16-24
# 8    Age of household reference person (HRP)1                     25-34
# 9    Age of household reference person (HRP)1                     25-34
# 10   Age of household reference person (HRP)1                     25-34
# 11   Age of household reference person (HRP)1                     25-34
# 12   Age of household reference person (HRP)1                     35-49
# 13   Age of household reference person (HRP)1                     35-49
# 14   Age of household reference person (HRP)1                     35-49
# 15   Age of household reference person (HRP)1                     35-49
# 16   Age of household reference person (HRP)1                     50-64
# 17   Age of household reference person (HRP)1                     50-64
# 18   Age of household reference person (HRP)1                     50-64
# 19   Age of household reference person (HRP)1                     50-64
# 20   Age of household reference person (HRP)1               65 and over
# 21   Age of household reference person (HRP)1               65 and over
# 22   Age of household reference person (HRP)1               65 and over
# 23   Age of household reference person (HRP)1               65 and over
# 24                                     Gender                      Male
# 25                                     Gender                      Male
# 26                                     Gender                      Male
# 27                                     Gender                      Male
# 28                                     Gender                    Female
# 29                                     Gender                    Female
# ..                                        ...                       ...
# 106                                Dependants            Has dependants
# 107                                Dependants            Has dependants
# 108                                Dependants             No dependants
# 109                                Dependants             No dependants
# 110                                Dependants             No dependants
# 111                                Dependants             No dependants
# 112                      Disability / illness  Has disability / illness
# 113                      Disability / illness  Has disability / illness
# 114                      Disability / illness  Has disability / illness
# 115                      Disability / illness  Has disability / illness
# 116                      Disability / illness   No disability / illness
# 117                      Disability / illness   No disability / illness
# 118                      Disability / illness   No disability / illness
# 119                      Disability / illness   No disability / illness
# 120                                 Area type                   Belfast
# 121                                 Area type                   Belfast
# 122                                 Area type                   Belfast
# 123                                 Area type                   Belfast
# 124                                 Area type  Urban, excluding Belfast
# 125                                 Area type  Urban, excluding Belfast
# 126                                 Area type  Urban, excluding Belfast
# 127                                 Area type  Urban, excluding Belfast
# 128                                 Area type                 All urban
# 129                                 Area type                 All urban
# 130                                 Area type                 All urban
# 131                                 Area type                 All urban
# 132                                 Area type                     Rural
# 133                                 Area type                     Rural
# 134                                 Area type                     Rural
# 135                                 Area type                     Rural
#
#     Measure Type    Unit
# 0        Percent  People
# 1        Percent  People
# 2        Percent  People
# 3        Percent  People
# 4        Percent  People
# 5        Percent  People
# 6        Percent  People
# 7        Percent  People
# 8        Percent  People
# 9        Percent  People
# 10       Percent  People
# 11       Percent  People
# 12       Percent  People
# 13       Percent  People
# 14       Percent  People
# 15       Percent  People
# 16       Percent  People
# 17       Percent  People
# 18       Percent  People
# 19       Percent  People
# 20       Percent  People
# 21       Percent  People
# 22       Percent  People
# 23       Percent  People
# 24       Percent  People
# 25       Percent  People
# 26       Percent  People
# 27       Percent  People
# 28       Percent  People
# 29       Percent  People
# ..           ...     ...
# 106      Percent  People
# 107      Percent  People
# 108      Percent  People
# 109      Percent  People
# 110      Percent  People
# 111      Percent  People
# 112      Percent  People
# 113      Percent  People
# 114      Percent  People
# 115      Percent  People
# 116      Percent  People
# 117      Percent  People
# 118      Percent  People
# 119      Percent  People
# 120      Percent  People
# 121      Percent  People
# 122      Percent  People
# 123      Percent  People
# 124      Percent  People
# 125      Percent  People
# 126      Percent  People
# 127      Percent  People
# 128      Percent  People
# 129      Percent  People
# 130      Percent  People
# 131      Percent  People
# 132      Percent  People
# 133      Percent  People
# 134      Percent  People
# 135      Percent  People
#
# [136 rows x 7 columns]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Value'] = pd.to_numeric(new_table['Value'], errors='coerce')

# %%
new_table = new_table[new_table['Value'].notnull() ]

# %%
new_table['Value'] = new_table['Value'].apply(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def user_perc(x,y):
    
    if str(x) == 'Unweighted base':
        return 'Count'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Alcohol related issue response'],row['Measure Type']), axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table['Category'] = new_table['Category'].str.rstrip('1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Demographic1'] = new_table['Category'].fillna('') + ' - ' + new_table['Sect'].fillna('')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Demographic1'] = new_table['Demographic1'].str.lstrip(' - ')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table = new_table[['Demographic1','Alcohol related issue response','Measure Type','Value','Unit']]

# %%
import urllib.request as request
import csv
r = request.urlopen('https://raw.githubusercontent.com/ONS-OpenData/ref_alcohol/master/codelists/demographic.csv').read().decode('utf8').split("\n")
reader = csv.reader(r)
for line in reader:
    print(line)
# Out:
# ['Label', 'Notation', 'Parent Notation', 'Sort Priority']
# ['All adults', 'all-adults', '', '1']
# ['Age of household reference person (HRP) - 16-24', 'hrp/16-24', '', '2']
# ['Age of household reference person (HRP) - 25-34', 'hrp/25-34', '', '3']
# ['Age of household reference person (HRP) - 35-49', 'hrp/35-49', '', '4']
# ['Age of household reference person (HRP) - 50-64', 'hrp/50-64', '', '5']
# ['Age of household reference person (HRP) - 65 and over', 'hrp/65plus', '', '6']
# ['Gender - Male', 'male', '', '7']
# ['Gender - Female', 'female', '', '8']
# ['Religion - Catholic', 'catholic', '', '9']
# ['Religion - Protestant', 'protestant', '', '10']
# ['Religion - Other', 'other', '', '11']
# ['Health and Social Care Trust - Belfast', 'hsct/belfast', '', '12']
# ['Health and Social Care Trust - Northern', 'hsct/northern', '', '13']
# ['Health and Social Care Trust - South Eastern', 'hsct/south-eastern', '', '14']
# ['Health and Social Care Trust - Southern', 'hsct/southern', '', '15']
# ['Health and Social Care Trust - Western', 'hsct/western', '', '16']
# ['Employment status - In paid employment', 'paid-employment', '', '17']
# ['Employment status - Not in paid employment', 'not-in-paid-employment', '', '18']
# ['Marital status - Single, that is never married', 'single', '', '19']
# ['Marital status - Married and living with husband / wife', 'married', '', '20']
# ['Marital status - Married and separated from husband / wife', 'married-separated', '', '21']
# ['Marital status - Divorced', 'divorced', '', '22']
# ['Marital status - Widowed', 'widowed', '', '23']
# ['Level of qualifications - Primary', 'primary', '', '24']
# ['Level of qualifications - Secondary', 'secondary', '', '25']
# ['Level of qualifications - Tertiary', 'tertiary', '', '26']
# ['Dependants - Has dependants', 'dependants', '', '27']
# ['Dependants - No dependants', 'no-dependants', '', '28']
# ['Disability / illness - Has disability / illness', 'disability', '', '29']
# ['Disability / illness - No disability / illness', 'no-disability', '', '30']
# ['Area type - Belfast', 'belfast', '', '31']
# ['Area type - Urban, excluding Belfast', 'urban-excl-belfast', '', '32']
# ['Area type - All urban', 'all-urban', '', '33']
# ['Area type - Rural', 'rural', '', '34']

# %%
import io
import requests
url="https://raw.githubusercontent.com/ONS-OpenData/ref_alcohol/master/codelists/demographic.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
Final_table = pd.merge(new_table, c, how = 'left', left_on = 'Demographic1', right_on = 'Label')

# %%
Final_table.columns = ['Demographic' if x=='Notation' else x for x in Final_table.columns]

# %%
Final_table['Alcohol related issue response'] = Final_table['Alcohol related issue response'].map(
    lambda x: {
        'Agree / strongly agree' : 'agree', 
        'Neither agree nor disagree' : 'neither',
        'Disagree / strongly disagree': 'disagree' ,
        'Unweighted base': 'unweighted-base'
        }.get(x, x))

# %%
Final_table = Final_table[['Demographic','Alcohol related issue response','Measure Type','Value','Unit']]

# %%
from pathlib import Path
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

Final_table.to_csv(destinationFolder / ('taba1.csv'), index = False)
