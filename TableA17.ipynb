# %% [markdown]
# Table A17: Comparison of main results from 2012 to 2016

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
inputFile = sourceFolder / 'ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Table A17')[0]
# Out:
# Loading in\ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx which has size 191159 bytes
# Table names: ['Table A17']

# %%
observations = tab.excel_ref('C5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<E12 0.431>, <C33 0.1>, <D16 'About the same'>, <E11 0.442>, <E23 0.138>, <F16 'Unweighted base'>, <C8 0.418>, <C28 'Total or a lot of confidence'>, <D17 0.824>, <C14 0.382>, <E28 'Little or no confidence'>, <F28 'Unweighted base'>, <F30 1078.0>, <D33 0.47>, <E8 0.41>, <E17 0.106>, <E5 0.403>, <F32 1125.0>, <F19 1013.0>, <D8 0.172>, <E21 0.104>, <E13 0.435>, <D21 0.786>, <C21 0.109>, <C19 0.1>, <F24 975.0>, <D18 0.82>, <D12 0.202>, <C29 0.094>, <C20 0.104>, <D10 0.196>, <D31 0.454>, <E30 0.472>, <D29 0.434>, <C24 0.06>, <C26 0.05>, <D30 0.443>, <E22 0.153>, <C9 0.461>, <E7 0.4>, <C23 0.056>, <F18 1028.0>, <E10 0.375>, <F7 1078.0>, <E33 0.43>, <C6 0.366>, <F31 1046.0>, <C22 0.047>, <F6 1105.0>, <E14 0.414>, <C7 0.44>, <D5 0.164>, <E26 0.12>, <F17 881.0>, <F25 1048.0>, <D23 0.806>, <D24 0.799>, <C16 'Better'>, <E29 0.472>, <E31 0.444>, <D20 0.791>, <F20 1077.0>, <C31 0.103>, <D25 0.835>, <D28 'Some confidence'>, <F23 1002.0>, <F14 1112.0>, <E24 0.141>, <C12 0.367>, <D13 0.223>, <D9 0.16>, <D14 0.204>, <E6 0.439>, <C17 '7%**'>, <C10 '42.9%**'>, <F26 981.0>, <F33 1096.0>, <C32 0.082>, <C5 0.433>, <E25 0.111>, <C30 0.084>, <C25 0.054>, <C18 0.09>, <D22 0.8>, <F29 917.0>, <F22 856.0>, <F21 1043.0>, <F5 945.0>, <E32 0.452>, <D19 0.797>, <F13 1151.0>, <F8 1159.0>, <F11 1096.0>, <E16 'Worse'>, <D11 0.202>, <D7 0.16>, <C13 0.341>, <D32 0.466>, <E18 0.09>, <C11 0.355>, <E20 0.105>, <E19 0.102>, <D26 0.83>, <D6 0.196>, <F10 935.0>, <F9 1126.0>, <F12 1067.0>, <E9 0.379>}

# %%
year = tab.excel_ref('B5').expand(DOWN).is_not_blank()
year
# Out:
# {<B31 2014.0>, <B6 2015.0>, <B26 2012.0>, <B20 2013.0>, <B10 2016.0>, <B17 2016.0>, <B22 2016.0>, <B13 2013.0>, <B24 2014.0>, <B33 2012.0>, <B30 2015.0>, <B29 2016.0>, <B25 2013.0>, <B18 2015.0>, <B11 2015.0>, <B19 2014.0>, <B7 2014.0>, <B12 2014.0>, <B32 2013.0>, <B23 2015.0>, <B9 2012.0>, <B28 'Year'>, <B5 2016.0>, <B8 2013.0>, <B14 2012.0>, <B16 'Year'>, <B21 2012.0>}

# %%
jh = tab.excel_ref('C4').expand(RIGHT).is_not_blank() -  tab.excel_ref('C15').expand(DOWN).is_not_blank()
jh
# Out:
# {<D4 '% neither agree nor disagree'>, <E4 '% Disagree / strongly disagree'>, <F4 'Unweighted base'>, <C4 '% agree'>}

# %%
gh = tab.excel_ref('C16').expand(RIGHT).is_not_blank() - tab.excel_ref('C27').expand(DOWN).is_not_blank()
gh
# Out:
# {<F16 'Unweighted base'>, <C16 'Better'>, <D16 'About the same'>, <E16 'Worse'>}

# %%
jk = tab.excel_ref('C28').expand(RIGHT).is_not_blank() - tab.excel_ref('C33').expand(DOWN).is_not_blank()
jk
# Out:
# {<C28 'Total or a lot of confidence'>, <E28 'Little or no confidence'>, <D28 'Some confidence'>, <F28 'Unweighted base'>}

# %%
tph = tab.excel_ref('A').expand(DOWN).by_index([5,17,29])
tph
# Out:
# {<A5 'I am concerned about alcohol related issues in my local area %'>, <A17 'Alcohol related issues in the local area % '>, <A29 ''>}

# %%
Dimensions = [
            HDim(jh,'Alcohol1',DIRECTLY,ABOVE),
            HDim(gh,'Alcohol2',DIRECTLY,ABOVE),
            HDim(jk,'Alcohol issue',DIRECTLY,ABOVE),
            HDim(year,'Year',DIRECTLY,LEFT),
            HDim(tph,'Statement',CLOSEST,ABOVE),
            HDimConst('Measure Type', 'Percentage'),
            HDimConst('Unit','People'),
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS                    DATAMARKER                        Alcohol1  \
# 0    0.433                           NaN                         % agree
# 1    0.164                           NaN    % neither agree nor disagree
# 2    0.403                           NaN  % Disagree / strongly disagree
# 3      945                           NaN                 Unweighted base
# 4    0.366                           NaN                         % agree
# 5    0.196                           NaN    % neither agree nor disagree
# 6    0.439                           NaN  % Disagree / strongly disagree
# 7     1105                           NaN                 Unweighted base
# 8     0.44                           NaN                         % agree
# 9     0.16                           NaN    % neither agree nor disagree
# 10     0.4                           NaN  % Disagree / strongly disagree
# 11    1078                           NaN                 Unweighted base
# 12   0.418                           NaN                         % agree
# 13   0.172                           NaN    % neither agree nor disagree
# 14    0.41                           NaN  % Disagree / strongly disagree
# 15    1159                           NaN                 Unweighted base
# 16   0.461                           NaN                         % agree
# 17    0.16                           NaN    % neither agree nor disagree
# 18   0.379                           NaN  % Disagree / strongly disagree
# 19    1126                           NaN                 Unweighted base
# 20    42.9                           %**                         % agree
# 21   0.196                           NaN    % neither agree nor disagree
# 22   0.375                           NaN  % Disagree / strongly disagree
# 23     935                           NaN                 Unweighted base
# 24   0.355                           NaN                         % agree
# 25   0.202                           NaN    % neither agree nor disagree
# 26   0.442                           NaN  % Disagree / strongly disagree
# 27    1096                           NaN                 Unweighted base
# 28   0.367                           NaN                         % agree
# 29   0.202                           NaN    % neither agree nor disagree
# ..     ...                           ...                             ...
# 78   0.111                           NaN  % Disagree / strongly disagree
# 79    1048                           NaN                 Unweighted base
# 80    0.05                           NaN                         % agree
# 81    0.83                           NaN    % neither agree nor disagree
# 82    0.12                           NaN  % Disagree / strongly disagree
# 83     981                           NaN                 Unweighted base
# 84          Total or a lot of confidence                         % agree
# 85                       Some confidence    % neither agree nor disagree
# 86               Little or no confidence  % Disagree / strongly disagree
# 87                       Unweighted base                 Unweighted base
# 88   0.094                           NaN                         % agree
# 89   0.434                           NaN    % neither agree nor disagree
# 90   0.472                           NaN  % Disagree / strongly disagree
# 91     917                           NaN                 Unweighted base
# 92   0.084                           NaN                         % agree
# 93   0.443                           NaN    % neither agree nor disagree
# 94   0.472                           NaN  % Disagree / strongly disagree
# 95    1078                           NaN                 Unweighted base
# 96   0.103                           NaN                         % agree
# 97   0.454                           NaN    % neither agree nor disagree
# 98   0.444                           NaN  % Disagree / strongly disagree
# 99    1046                           NaN                 Unweighted base
# 100  0.082                           NaN                         % agree
# 101  0.466                           NaN    % neither agree nor disagree
# 102  0.452                           NaN  % Disagree / strongly disagree
# 103   1125                           NaN                 Unweighted base
# 104    0.1                           NaN                         % agree
# 105   0.47                           NaN    % neither agree nor disagree
# 106   0.43                           NaN  % Disagree / strongly disagree
# 107   1096                           NaN                 Unweighted base
#
#             Alcohol2                 Alcohol issue    Year  \
# 0               None                          None  2016.0
# 1               None                          None  2016.0
# 2               None                          None  2016.0
# 3               None                          None  2016.0
# 4               None                          None  2015.0
# 5               None                          None  2015.0
# 6               None                          None  2015.0
# 7               None                          None  2015.0
# 8               None                          None  2014.0
# 9               None                          None  2014.0
# 10              None                          None  2014.0
# 11              None                          None  2014.0
# 12              None                          None  2013.0
# 13              None                          None  2013.0
# 14              None                          None  2013.0
# 15              None                          None  2013.0
# 16              None                          None  2012.0
# 17              None                          None  2012.0
# 18              None                          None  2012.0
# 19              None                          None  2012.0
# 20              None                          None  2016.0
# 21              None                          None  2016.0
# 22              None                          None  2016.0
# 23              None                          None  2016.0
# 24              None                          None  2015.0
# 25              None                          None  2015.0
# 26              None                          None  2015.0
# 27              None                          None  2015.0
# 28              None                          None  2014.0
# 29              None                          None  2014.0
# ..               ...                           ...     ...
# 78             Worse                          None  2013.0
# 79   Unweighted base                          None  2013.0
# 80            Better                          None  2012.0
# 81    About the same                          None  2012.0
# 82             Worse                          None  2012.0
# 83   Unweighted base                          None  2012.0
# 84            Better  Total or a lot of confidence    Year
# 85    About the same               Some confidence    Year
# 86             Worse       Little or no confidence    Year
# 87   Unweighted base               Unweighted base    Year
# 88            Better  Total or a lot of confidence  2016.0
# 89    About the same               Some confidence  2016.0
# 90             Worse       Little or no confidence  2016.0
# 91   Unweighted base               Unweighted base  2016.0
# 92            Better  Total or a lot of confidence  2015.0
# 93    About the same               Some confidence  2015.0
# 94             Worse       Little or no confidence  2015.0
# 95   Unweighted base               Unweighted base  2015.0
# 96            Better  Total or a lot of confidence  2014.0
# 97    About the same               Some confidence  2014.0
# 98             Worse       Little or no confidence  2014.0
# 99   Unweighted base               Unweighted base  2014.0
# 100           Better  Total or a lot of confidence  2013.0
# 101   About the same               Some confidence  2013.0
# 102            Worse       Little or no confidence  2013.0
# 103  Unweighted base               Unweighted base  2013.0
# 104           Better  Total or a lot of confidence  2012.0
# 105   About the same               Some confidence  2012.0
# 106            Worse       Little or no confidence  2012.0
# 107  Unweighted base               Unweighted base  2012.0
#
#                                              Statement Measure Type    Unit
# 0    I am concerned about alcohol related issues in...   Percentage  People
# 1    I am concerned about alcohol related issues in...   Percentage  People
# 2    I am concerned about alcohol related issues in...   Percentage  People
# 3    I am concerned about alcohol related issues in...   Percentage  People
# 4    I am concerned about alcohol related issues in...   Percentage  People
# 5    I am concerned about alcohol related issues in...   Percentage  People
# 6    I am concerned about alcohol related issues in...   Percentage  People
# 7    I am concerned about alcohol related issues in...   Percentage  People
# 8    I am concerned about alcohol related issues in...   Percentage  People
# 9    I am concerned about alcohol related issues in...   Percentage  People
# 10   I am concerned about alcohol related issues in...   Percentage  People
# 11   I am concerned about alcohol related issues in...   Percentage  People
# 12   I am concerned about alcohol related issues in...   Percentage  People
# 13   I am concerned about alcohol related issues in...   Percentage  People
# 14   I am concerned about alcohol related issues in...   Percentage  People
# 15   I am concerned about alcohol related issues in...   Percentage  People
# 16   I am concerned about alcohol related issues in...   Percentage  People
# 17   I am concerned about alcohol related issues in...   Percentage  People
# 18   I am concerned about alcohol related issues in...   Percentage  People
# 19   I am concerned about alcohol related issues in...   Percentage  People
# 20   I am concerned about alcohol related issues in...   Percentage  People
# 21   I am concerned about alcohol related issues in...   Percentage  People
# 22   I am concerned about alcohol related issues in...   Percentage  People
# 23   I am concerned about alcohol related issues in...   Percentage  People
# 24   I am concerned about alcohol related issues in...   Percentage  People
# 25   I am concerned about alcohol related issues in...   Percentage  People
# 26   I am concerned about alcohol related issues in...   Percentage  People
# 27   I am concerned about alcohol related issues in...   Percentage  People
# 28   I am concerned about alcohol related issues in...   Percentage  People
# 29   I am concerned about alcohol related issues in...   Percentage  People
# ..                                                 ...          ...     ...
# 78         Alcohol related issues in the local area %    Percentage  People
# 79         Alcohol related issues in the local area %    Percentage  People
# 80         Alcohol related issues in the local area %    Percentage  People
# 81         Alcohol related issues in the local area %    Percentage  People
# 82         Alcohol related issues in the local area %    Percentage  People
# 83         Alcohol related issues in the local area %    Percentage  People
# 84         Alcohol related issues in the local area %    Percentage  People
# 85         Alcohol related issues in the local area %    Percentage  People
# 86         Alcohol related issues in the local area %    Percentage  People
# 87         Alcohol related issues in the local area %    Percentage  People
# 88                                                       Percentage  People
# 89                                                       Percentage  People
# 90                                                       Percentage  People
# 91                                                       Percentage  People
# 92                                                       Percentage  People
# 93                                                       Percentage  People
# 94                                                       Percentage  People
# 95                                                       Percentage  People
# 96                                                       Percentage  People
# 97                                                       Percentage  People
# 98                                                       Percentage  People
# 99                                                       Percentage  People
# 100                                                      Percentage  People
# 101                                                      Percentage  People
# 102                                                      Percentage  People
# 103                                                      Percentage  People
# 104                                                      Percentage  People
# 105                                                      Percentage  People
# 106                                                      Percentage  People
# 107                                                      Percentage  People
#
# [108 rows x 9 columns]

# %%
new_table['Statement'] = new_table['Statement'].map(
    lambda x: {
        '' : 'Overall level of confidence'
        }.get(x, x))

# %%
new_table.columns = ['Response' if x=='OBS' else x for x in new_table.columns]

# %%
new_table = new_table[new_table['Response'] != '']

# %%
new_table.dtypes
# Out:
# Response         object
# DATAMARKER       object
# Alcohol1         object
# Alcohol2         object
# Alcohol issue    object
# Year             object
# Statement        object
# Measure Type     object
# Unit             object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Response DATAMARKER                        Alcohol1         Alcohol2  \
# 103     1125        NaN                 Unweighted base  Unweighted base
# 104      0.1        NaN                         % agree           Better
# 105     0.47        NaN    % neither agree nor disagree   About the same
# 106     0.43        NaN  % Disagree / strongly disagree            Worse
# 107     1096        NaN                 Unweighted base  Unweighted base
#
#                     Alcohol issue    Year                    Statement  \
# 103               Unweighted base  2013.0  Overall level of confidence
# 104  Total or a lot of confidence  2012.0  Overall level of confidence
# 105               Some confidence  2012.0  Overall level of confidence
# 106       Little or no confidence  2012.0  Overall level of confidence
# 107               Unweighted base  2012.0  Overall level of confidence
#
#     Measure Type    Unit
# 103   Percentage  People
# 104   Percentage  People
# 105   Percentage  People
# 106   Percentage  People
# 107   Percentage  People

# %%
new_table.head()
# Out:
#   Response DATAMARKER                        Alcohol1 Alcohol2 Alcohol issue  \
# 0    0.433        NaN                         % agree     None          None
# 1    0.164        NaN    % neither agree nor disagree     None          None
# 2    0.403        NaN  % Disagree / strongly disagree     None          None
# 3      945        NaN                 Unweighted base     None          None
# 4    0.366        NaN                         % agree     None          None
#
#      Year                                          Statement Measure Type  \
# 0  2016.0  I am concerned about alcohol related issues in...   Percentage
# 1  2016.0  I am concerned about alcohol related issues in...   Percentage
# 2  2016.0  I am concerned about alcohol related issues in...   Percentage
# 3  2016.0  I am concerned about alcohol related issues in...   Percentage
# 4  2015.0  I am concerned about alcohol related issues in...   Percentage
#
#      Unit
# 0  People
# 1  People
# 2  People
# 3  People
# 4  People

# %%
def user_perc(x,y,z,p):
    
    if str(x) == 'I am concerned about alcohol related issues in my local area %':
        return y
    if str(x) == 'Alcohol related issues in the local area % ':
        return z 
    else:
        return p
    
new_table['Alcohol issue'] = new_table.apply(lambda row: user_perc(row['Statement'],row['Alcohol1'],row['Alcohol2'],row['Alcohol issue']), axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
new_table['Response'] = pd.to_numeric(new_table['Response'], errors='coerce')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Year'] = new_table['Year'].apply(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Response'] = new_table['Response'].apply(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def user_perc(x,y):
    
    if str(x) == 'Unweighted base':
        return 'Number'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Alcohol issue'],row['Measure Type']), axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table['Statement'] = new_table['Statement'].str.rstrip('%')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table = new_table[['Year','Alcohol issue','Statement','Measure Type','Response','Unit']]

# %%
new_table.head(5)
# Out:
#    Year                   Alcohol issue  \
# 0  2016                         % agree
# 1  2016    % neither agree nor disagree
# 2  2016  % Disagree / strongly disagree
# 3  2016                 Unweighted base
# 4  2015                         % agree
#
#                                            Statement Measure Type Response  \
# 0  I am concerned about alcohol related issues in...   Percentage    0.433
# 1  I am concerned about alcohol related issues in...   Percentage    0.164
# 2  I am concerned about alcohol related issues in...   Percentage    0.403
# 3  I am concerned about alcohol related issues in...       Number    945.0
# 4  I am concerned about alcohol related issues in...   Percentage    0.366
#
#      Unit
# 0  People
# 1  People
# 2  People
# 3  People
# 4  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('taba17.csv'), index = False)
