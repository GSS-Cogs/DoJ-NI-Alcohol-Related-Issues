# %% [markdown]
# Table A17: Comparison of main results from 2012 to 2016

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
inputFile = sourceFolder / 'ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
Value = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(Value.content)

# %% [markdown]
# https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Table A17')[0]
# Out:
# Loading in\ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx which has size 191159 bytes
# Table names: ['Table A17']

# %%
observations = tab.excel_ref('C5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<D31 0.454>, <E24 0.141>, <D28 'Some confidence'>, <E28 'Little or no confidence'>, <F5 945.0>, <C11 0.355>, <C26 0.05>, <D19 0.797>, <E20 0.105>, <E19 0.102>, <E17 0.106>, <E5 0.403>, <C12 0.367>, <C28 'Total or a lot of confidence'>, <F16 'Unweighted base'>, <D33 0.47>, <E8 0.41>, <F7 1078.0>, <D6 0.196>, <F32 1125.0>, <D8 0.172>, <E10 0.375>, <C30 0.084>, <C25 0.054>, <C13 0.341>, <E30 0.472>, <C24 0.06>, <D10 0.196>, <E29 0.472>, <E6 0.439>, <C9 0.461>, <E12 0.431>, <E11 0.442>, <E16 'Worse'>, <F31 1046.0>, <F9 1126.0>, <F12 1067.0>, <C10 '42.9%**'>, <D22 0.8>, <F28 'Unweighted base'>, <F29 917.0>, <D17 0.824>, <C5 0.433>, <E14 0.414>, <C8 0.418>, <E32 0.452>, <F11 1096.0>, <F8 1159.0>, <F21 1043.0>, <F22 856.0>, <F14 1112.0>, <D32 0.466>, <D13 0.223>, <D18 0.82>, <D14 0.204>, <C20 0.104>, <F30 1078.0>, <D20 0.791>, <E7 0.4>, <F26 981.0>, <F18 1028.0>, <E22 0.153>, <C33 0.1>, <C18 0.09>, <C16 'Better'>, <C22 0.047>, <E21 0.104>, <E9 0.379>, <F13 1151.0>, <C6 0.366>, <E26 0.12>, <E23 0.138>, <C19 0.1>, <F24 975.0>, <E18 0.09>, <C29 0.094>, <D5 0.164>, <F17 881.0>, <D11 0.202>, <C31 0.103>, <D7 0.16>, <D25 0.835>, <D26 0.83>, <F10 935.0>, <D29 0.434>, <D30 0.443>, <C23 0.056>, <F23 1002.0>, <D9 0.16>, <F33 1096.0>, <C32 0.082>, <F6 1105.0>, <E25 0.111>, <E13 0.435>, <E33 0.43>, <D21 0.786>, <C21 0.109>, <D23 0.806>, <F25 1048.0>, <F19 1013.0>, <C17 '7%**'>, <D24 0.799>, <D16 'About the same'>, <C14 0.382>, <D12 0.202>, <C7 0.44>, <E31 0.444>, <F20 1077.0>}

# %%
Period = tab.excel_ref('B5').expand(DOWN).is_not_blank()
Period
# Out:
# {<B7 2014.0>, <B19 2014.0>, <B18 2015.0>, <B12 2014.0>, <B8 2013.0>, <B23 2015.0>, <B5 2016.0>, <B14 2012.0>, <B16 'Year'>, <B9 2012.0>, <B6 2015.0>, <B20 2013.0>, <B22 2016.0>, <B26 2012.0>, <B31 2014.0>, <B10 2016.0>, <B21 2012.0>, <B30 2015.0>, <B13 2013.0>, <B29 2016.0>, <B28 'Year'>, <B33 2012.0>, <B17 2016.0>, <B11 2015.0>, <B32 2013.0>, <B24 2014.0>, <B25 2013.0>}

# %%
jh = tab.excel_ref('C4').expand(RIGHT).is_not_blank() -  tab.excel_ref('C15').expand(DOWN).is_not_blank()
jh
# Out:
# {<C4 '% agree'>, <E4 '% Disagree / strongly disagree'>, <D4 '% neither agree nor disagree'>, <F4 'Unweighted base'>}

# %%
gh = tab.excel_ref('C16').expand(RIGHT).is_not_blank() - tab.excel_ref('C27').expand(DOWN).is_not_blank()
gh
# Out:
# {<D16 'About the same'>, <C16 'Better'>, <E16 'Worse'>, <F16 'Unweighted base'>}

# %%
jk = tab.excel_ref('C28').expand(RIGHT).is_not_blank() - tab.excel_ref('C33').expand(DOWN).is_not_blank()
jk
# Out:
# {<E28 'Little or no confidence'>, <D28 'Some confidence'>, <F28 'Unweighted base'>, <C28 'Total or a lot of confidence'>}

# %%
tph = tab.excel_ref('A').expand(DOWN).by_index([5,17,29])
tph
# Out:
# {<A5 'I am concerned about alcohol related issues in my local area %'>, <A17 'Alcohol related issues in the local area % '>, <A29 ''>}

# %%
Dimensions = [
            HDim(jh,'Alcohol1',DIRECTLY,ABOVE),
            HDim(gh,'Alcohol2',DIRECTLY,ABOVE),
            HDim(jk,'Alcohol related issue response',DIRECTLY,ABOVE),
            HDim(Period,'Period',DIRECTLY,LEFT),
            HDim(tph,'Statement',CLOSEST,ABOVE),
            HDimConst('Measure Type', 'Percent'),
            HDimConst('Unit','People'),
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
Final_table = c1.topandas()
Final_table
# Out:
#        OBS                    DATAMARKER                        Alcohol1  \
# 0    0.433                           NaN                         % agree
# 1    0.164                           NaN    % neither agree nor disagree
# 2    0.403                           NaN  % Disagree / strongly disagree
# 3      945                           NaN                 Unweighted base
# 4    0.366                           NaN                         % agree
# 5    0.196                           NaN    % neither agree nor disagree
# 6    0.439                           NaN  % Disagree / strongly disagree
# 7     1105                           NaN                 Unweighted base
# 8     0.44                           NaN                         % agree
# 9     0.16                           NaN    % neither agree nor disagree
# 10     0.4                           NaN  % Disagree / strongly disagree
# 11    1078                           NaN                 Unweighted base
# 12   0.418                           NaN                         % agree
# 13   0.172                           NaN    % neither agree nor disagree
# 14    0.41                           NaN  % Disagree / strongly disagree
# 15    1159                           NaN                 Unweighted base
# 16   0.461                           NaN                         % agree
# 17    0.16                           NaN    % neither agree nor disagree
# 18   0.379                           NaN  % Disagree / strongly disagree
# 19    1126                           NaN                 Unweighted base
# 20    42.9                           %**                         % agree
# 21   0.196                           NaN    % neither agree nor disagree
# 22   0.375                           NaN  % Disagree / strongly disagree
# 23     935                           NaN                 Unweighted base
# 24   0.355                           NaN                         % agree
# 25   0.202                           NaN    % neither agree nor disagree
# 26   0.442                           NaN  % Disagree / strongly disagree
# 27    1096                           NaN                 Unweighted base
# 28   0.367                           NaN                         % agree
# 29   0.202                           NaN    % neither agree nor disagree
# ..     ...                           ...                             ...
# 78   0.111                           NaN  % Disagree / strongly disagree
# 79    1048                           NaN                 Unweighted base
# 80    0.05                           NaN                         % agree
# 81    0.83                           NaN    % neither agree nor disagree
# 82    0.12                           NaN  % Disagree / strongly disagree
# 83     981                           NaN                 Unweighted base
# 84          Total or a lot of confidence                         % agree
# 85                       Some confidence    % neither agree nor disagree
# 86               Little or no confidence  % Disagree / strongly disagree
# 87                       Unweighted base                 Unweighted base
# 88   0.094                           NaN                         % agree
# 89   0.434                           NaN    % neither agree nor disagree
# 90   0.472                           NaN  % Disagree / strongly disagree
# 91     917                           NaN                 Unweighted base
# 92   0.084                           NaN                         % agree
# 93   0.443                           NaN    % neither agree nor disagree
# 94   0.472                           NaN  % Disagree / strongly disagree
# 95    1078                           NaN                 Unweighted base
# 96   0.103                           NaN                         % agree
# 97   0.454                           NaN    % neither agree nor disagree
# 98   0.444                           NaN  % Disagree / strongly disagree
# 99    1046                           NaN                 Unweighted base
# 100  0.082                           NaN                         % agree
# 101  0.466                           NaN    % neither agree nor disagree
# 102  0.452                           NaN  % Disagree / strongly disagree
# 103   1125                           NaN                 Unweighted base
# 104    0.1                           NaN                         % agree
# 105   0.47                           NaN    % neither agree nor disagree
# 106   0.43                           NaN  % Disagree / strongly disagree
# 107   1096                           NaN                 Unweighted base
#
#             Alcohol2 Alcohol related issue response  Period  \
# 0               None                           None  2016.0
# 1               None                           None  2016.0
# 2               None                           None  2016.0
# 3               None                           None  2016.0
# 4               None                           None  2015.0
# 5               None                           None  2015.0
# 6               None                           None  2015.0
# 7               None                           None  2015.0
# 8               None                           None  2014.0
# 9               None                           None  2014.0
# 10              None                           None  2014.0
# 11              None                           None  2014.0
# 12              None                           None  2013.0
# 13              None                           None  2013.0
# 14              None                           None  2013.0
# 15              None                           None  2013.0
# 16              None                           None  2012.0
# 17              None                           None  2012.0
# 18              None                           None  2012.0
# 19              None                           None  2012.0
# 20              None                           None  2016.0
# 21              None                           None  2016.0
# 22              None                           None  2016.0
# 23              None                           None  2016.0
# 24              None                           None  2015.0
# 25              None                           None  2015.0
# 26              None                           None  2015.0
# 27              None                           None  2015.0
# 28              None                           None  2014.0
# 29              None                           None  2014.0
# ..               ...                            ...     ...
# 78             Worse                           None  2013.0
# 79   Unweighted base                           None  2013.0
# 80            Better                           None  2012.0
# 81    About the same                           None  2012.0
# 82             Worse                           None  2012.0
# 83   Unweighted base                           None  2012.0
# 84            Better   Total or a lot of confidence    Year
# 85    About the same                Some confidence    Year
# 86             Worse        Little or no confidence    Year
# 87   Unweighted base                Unweighted base    Year
# 88            Better   Total or a lot of confidence  2016.0
# 89    About the same                Some confidence  2016.0
# 90             Worse        Little or no confidence  2016.0
# 91   Unweighted base                Unweighted base  2016.0
# 92            Better   Total or a lot of confidence  2015.0
# 93    About the same                Some confidence  2015.0
# 94             Worse        Little or no confidence  2015.0
# 95   Unweighted base                Unweighted base  2015.0
# 96            Better   Total or a lot of confidence  2014.0
# 97    About the same                Some confidence  2014.0
# 98             Worse        Little or no confidence  2014.0
# 99   Unweighted base                Unweighted base  2014.0
# 100           Better   Total or a lot of confidence  2013.0
# 101   About the same                Some confidence  2013.0
# 102            Worse        Little or no confidence  2013.0
# 103  Unweighted base                Unweighted base  2013.0
# 104           Better   Total or a lot of confidence  2012.0
# 105   About the same                Some confidence  2012.0
# 106            Worse        Little or no confidence  2012.0
# 107  Unweighted base                Unweighted base  2012.0
#
#                                              Statement Measure Type    Unit
# 0    I am concerned about alcohol related issues in...      Percent  People
# 1    I am concerned about alcohol related issues in...      Percent  People
# 2    I am concerned about alcohol related issues in...      Percent  People
# 3    I am concerned about alcohol related issues in...      Percent  People
# 4    I am concerned about alcohol related issues in...      Percent  People
# 5    I am concerned about alcohol related issues in...      Percent  People
# 6    I am concerned about alcohol related issues in...      Percent  People
# 7    I am concerned about alcohol related issues in...      Percent  People
# 8    I am concerned about alcohol related issues in...      Percent  People
# 9    I am concerned about alcohol related issues in...      Percent  People
# 10   I am concerned about alcohol related issues in...      Percent  People
# 11   I am concerned about alcohol related issues in...      Percent  People
# 12   I am concerned about alcohol related issues in...      Percent  People
# 13   I am concerned about alcohol related issues in...      Percent  People
# 14   I am concerned about alcohol related issues in...      Percent  People
# 15   I am concerned about alcohol related issues in...      Percent  People
# 16   I am concerned about alcohol related issues in...      Percent  People
# 17   I am concerned about alcohol related issues in...      Percent  People
# 18   I am concerned about alcohol related issues in...      Percent  People
# 19   I am concerned about alcohol related issues in...      Percent  People
# 20   I am concerned about alcohol related issues in...      Percent  People
# 21   I am concerned about alcohol related issues in...      Percent  People
# 22   I am concerned about alcohol related issues in...      Percent  People
# 23   I am concerned about alcohol related issues in...      Percent  People
# 24   I am concerned about alcohol related issues in...      Percent  People
# 25   I am concerned about alcohol related issues in...      Percent  People
# 26   I am concerned about alcohol related issues in...      Percent  People
# 27   I am concerned about alcohol related issues in...      Percent  People
# 28   I am concerned about alcohol related issues in...      Percent  People
# 29   I am concerned about alcohol related issues in...      Percent  People
# ..                                                 ...          ...     ...
# 78         Alcohol related issues in the local area %       Percent  People
# 79         Alcohol related issues in the local area %       Percent  People
# 80         Alcohol related issues in the local area %       Percent  People
# 81         Alcohol related issues in the local area %       Percent  People
# 82         Alcohol related issues in the local area %       Percent  People
# 83         Alcohol related issues in the local area %       Percent  People
# 84         Alcohol related issues in the local area %       Percent  People
# 85         Alcohol related issues in the local area %       Percent  People
# 86         Alcohol related issues in the local area %       Percent  People
# 87         Alcohol related issues in the local area %       Percent  People
# 88                                                          Percent  People
# 89                                                          Percent  People
# 90                                                          Percent  People
# 91                                                          Percent  People
# 92                                                          Percent  People
# 93                                                          Percent  People
# 94                                                          Percent  People
# 95                                                          Percent  People
# 96                                                          Percent  People
# 97                                                          Percent  People
# 98                                                          Percent  People
# 99                                                          Percent  People
# 100                                                         Percent  People
# 101                                                         Percent  People
# 102                                                         Percent  People
# 103                                                         Percent  People
# 104                                                         Percent  People
# 105                                                         Percent  People
# 106                                                         Percent  People
# 107                                                         Percent  People
#
# [108 rows x 9 columns]

# %%
Final_table['Statement'] = Final_table['Statement'].map(
    lambda x: {
        '' : 'Overall level of confidence'
        }.get(x, x))

# %%
Final_table.columns = ['Value' if x=='OBS' else x for x in Final_table.columns]

# %%
Final_table = Final_table[Final_table['Value'] != '']

# %%
Final_table.dtypes
# Out:
# Value                             object
# DATAMARKER                        object
# Alcohol1                          object
# Alcohol2                          object
# Alcohol related issue response    object
# Period                            object
# Statement                         object
# Measure Type                      object
# Unit                              object
# dtype: object

# %%
Final_table.tail(5)
# Out:
#     Value DATAMARKER                        Alcohol1         Alcohol2  \
# 103  1125        NaN                 Unweighted base  Unweighted base
# 104   0.1        NaN                         % agree           Better
# 105  0.47        NaN    % neither agree nor disagree   About the same
# 106  0.43        NaN  % Disagree / strongly disagree            Worse
# 107  1096        NaN                 Unweighted base  Unweighted base
#
#     Alcohol related issue response  Period                    Statement  \
# 103                Unweighted base  2013.0  Overall level of confidence
# 104   Total or a lot of confidence  2012.0  Overall level of confidence
# 105                Some confidence  2012.0  Overall level of confidence
# 106        Little or no confidence  2012.0  Overall level of confidence
# 107                Unweighted base  2012.0  Overall level of confidence
#
#     Measure Type    Unit
# 103      Percent  People
# 104      Percent  People
# 105      Percent  People
# 106      Percent  People
# 107      Percent  People

# %%
Final_table.head()
# Out:
#    Value DATAMARKER                        Alcohol1 Alcohol2  \
# 0  0.433        NaN                         % agree     None
# 1  0.164        NaN    % neither agree nor disagree     None
# 2  0.403        NaN  % Disagree / strongly disagree     None
# 3    945        NaN                 Unweighted base     None
# 4  0.366        NaN                         % agree     None
#
#   Alcohol related issue response  Period  \
# 0                           None  2016.0
# 1                           None  2016.0
# 2                           None  2016.0
# 3                           None  2016.0
# 4                           None  2015.0
#
#                                            Statement Measure Type    Unit
# 0  I am concerned about alcohol related issues in...      Percent  People
# 1  I am concerned about alcohol related issues in...      Percent  People
# 2  I am concerned about alcohol related issues in...      Percent  People
# 3  I am concerned about alcohol related issues in...      Percent  People
# 4  I am concerned about alcohol related issues in...      Percent  People

# %%
def user_perc(x,y,z,p):
    
    if str(x) == 'I am concerned about alcohol related issues in my local area %':
        return y
    if str(x) == 'Alcohol related issues in the local area % ':
        return z 
    else:
        return p
    
Final_table['Alcohol related issue response'] = Final_table.apply(lambda row: user_perc(row['Statement'],row['Alcohol1'],row['Alcohol2'],row['Alcohol related issue response']), axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
Final_table['Value'] = pd.to_numeric(Final_table['Value'], errors='coerce')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Final_table['Period'] = pd.to_numeric(Final_table['Period'], errors='coerce').fillna(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Final_table['Period'] = Final_table['Period'].apply(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Final_table['Period'] = Final_table['Period'].apply(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Final_table['Period'] = 'year/' + Final_table['Period']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Final_table['Value'] = Final_table['Value'].apply(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def user_perc(x,y):
    
    if str(x) == 'Unweighted base':
        return 'Count'
    else:
        return y
    
Final_table['Measure Type'] = Final_table.apply(lambda row: user_perc(row['Alcohol related issue response'],row['Measure Type']), axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Final_table['Statement'] = Final_table['Statement'].str.rstrip('%')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Final_table['Alcohol related issue response'] = Final_table['Alcohol related issue response'].map(
    lambda x: {
        '% agree' : 'agree', 
        '% neither agree nor disagree' : 'neither',
        '% Disagree / strongly disagree': 'disagree' ,
        'Unweighted base': 'unweighted-base'
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Final_table['Statement'] = Final_table['Statement'].map(
    lambda x: {
        'I am concerned about alcohol related issues in my local area ' : 'concerned', 
        'Alcohol related issues in the local area % ' : 'change-perception',
        'Overall level of confidence': 'confidence-level' ,
       }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Final_table = Final_table[['Period','Alcohol related issue response','Statement','Measure Type','Value','Unit']]

# %%
Final_table.head(5)
# Out:
#       Period Alcohol related issue response  Statement Measure Type  Value  \
# 0  year/2016                          agree  concerned      Percent  0.433
# 1  year/2016                        neither  concerned      Percent  0.164
# 2  year/2016                       disagree  concerned      Percent  0.403
# 3  year/2016                unweighted-base  concerned        Count  945.0
# 4  year/2015                          agree  concerned      Percent  0.366
#
#      Unit
# 0  People
# 1  People
# 2  People
# 3  People
# 4  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

Final_table.to_csv(destinationFolder / ('table17.csv'), index = False)
