# %% [markdown]
# Table A16: Comparison of main results from 2015 to 2016

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
inputFile = sourceFolder / 'ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# https://www.justice-ni.gov.uk/sites/default/files/publications/justice/ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Table A16')[0]
# Out:
# Loading in\ni-omnibus-survey-oct-2016-alcohol-drugs-tabular.xlsx which has size 191159 bytes
# Table names: ['Table A16']

# %%
observations = tab.excel_ref('C5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<E13 0.106>, <C9 0.355>, <C16 0.047>, <E5 0.403>, <D17 0.806>, <C21 0.094>, <E14 0.09>, <D16 0.8>, <C14 0.09>, <F16 856.0>, <D9 0.202>, <C12 'Better'>, <D6 0.196>, <E12 'Worse'>, <D12 'About the same'>, <F22 1078.0>, <F5 945.0>, <E17 0.138>, <C22 0.084>, <F6 1105.0>, <F12 'Unweighted base'>, <E9 0.442>, <E20 'Little or no confidence'>, <F20 'Unweighted base'>, <D8 0.196>, <F13 881.0>, <C20 'Total or a lot of confidence'>, <F21 917.0>, <E22 0.472>, <F14 1028.0>, <D20 'Some confidence'>, <C8 '42.9%**'>, <F17 1002.0>, <C13 0.07>, <D5 0.164>, <E21 0.472>, <C5 '43.3%**'>, <F9 1096.0>, <F8 935.0>, <D21 0.434>, <D22 0.443>, <D13 0.824>, <C17 0.056>, <E16 0.153>, <D14 0.82>, <E6 0.439>, <C6 0.366>, <E8 '37.5%**'>}

# %%
year = tab.excel_ref('B5').expand(DOWN).is_not_blank()
year
# Out:
# {<B21 2016.0>, <B12 'Year'>, <B14 2015.0>, <B9 2015.0>, <B13 2016.0>, <B22 2015.0>, <B17 2015.0>, <B5 2016.0>, <B16 2016.0>, <B20 'Year'>, <B8 2016.0>, <B6 2015.0>}

# %%
jh = tab.excel_ref('C4').expand(RIGHT).is_not_blank() -  tab.excel_ref('C11').expand(DOWN).is_not_blank()
jh
# Out:
# {<E4 '% Disagree / strongly disagree'>, <C4 '% agree'>, <D4 '% neither agree nor disagree'>, <F4 'Unweighted base'>}

# %%
gh = tab.excel_ref('C12').expand(RIGHT).is_not_blank() - tab.excel_ref('C20').expand(DOWN).is_not_blank()
gh
# Out:
# {<D12 'About the same'>, <F12 'Unweighted base'>, <E12 'Worse'>, <C12 'Better'>}

# %%
jk = tab.excel_ref('C20').expand(RIGHT).is_not_blank() - tab.excel_ref('C22').expand(DOWN).is_not_blank()
jk
# Out:
# {<D20 'Some confidence'>, <C20 'Total or a lot of confidence'>, <E20 'Little or no confidence'>, <F20 'Unweighted base'>}

# %%
tph = tab.excel_ref('A').expand(DOWN).by_index([5,13,21])
tph
# Out:
# {<A13 'Alcohol related issues in the local area % '>, <A5 'I am concerned about alcohol related issues in my local area %'>, <A21 ''>}

# %%
Dimensions = [
            HDim(jh,'Alcohol1',DIRECTLY,ABOVE),
            HDim(gh,'Alcohol2',DIRECTLY,ABOVE),
            HDim(jk,'Alcohol issue',DIRECTLY,ABOVE),
            HDim(year,'Year',DIRECTLY,LEFT),
            HDim(tph,'Statement',CLOSEST,ABOVE),
            HDimConst('Measure Type', 'Percentage'),
            HDimConst('Unit','People'),
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#       OBS                    DATAMARKER                        Alcohol1  \
# 0    43.3                           %**                         % agree
# 1   0.164                           NaN    % neither agree nor disagree
# 2   0.403                           NaN  % Disagree / strongly disagree
# 3     945                           NaN                 Unweighted base
# 4   0.366                           NaN                         % agree
# 5   0.196                           NaN    % neither agree nor disagree
# 6   0.439                           NaN  % Disagree / strongly disagree
# 7    1105                           NaN                 Unweighted base
# 8    42.9                           %**                         % agree
# 9   0.196                           NaN    % neither agree nor disagree
# 10   37.5                           %**  % Disagree / strongly disagree
# 11    935                           NaN                 Unweighted base
# 12  0.355                           NaN                         % agree
# 13  0.202                           NaN    % neither agree nor disagree
# 14  0.442                           NaN  % Disagree / strongly disagree
# 15   1096                           NaN                 Unweighted base
# 16                               Better                         % agree
# 17                       About the same    % neither agree nor disagree
# 18                                Worse  % Disagree / strongly disagree
# 19                      Unweighted base                 Unweighted base
# 20   0.07                           NaN                         % agree
# 21  0.824                           NaN    % neither agree nor disagree
# 22  0.106                           NaN  % Disagree / strongly disagree
# 23    881                           NaN                 Unweighted base
# 24   0.09                           NaN                         % agree
# 25   0.82                           NaN    % neither agree nor disagree
# 26   0.09                           NaN  % Disagree / strongly disagree
# 27   1028                           NaN                 Unweighted base
# 28  0.047                           NaN                         % agree
# 29    0.8                           NaN    % neither agree nor disagree
# 30  0.153                           NaN  % Disagree / strongly disagree
# 31    856                           NaN                 Unweighted base
# 32  0.056                           NaN                         % agree
# 33  0.806                           NaN    % neither agree nor disagree
# 34  0.138                           NaN  % Disagree / strongly disagree
# 35   1002                           NaN                 Unweighted base
# 36         Total or a lot of confidence                         % agree
# 37                      Some confidence    % neither agree nor disagree
# 38              Little or no confidence  % Disagree / strongly disagree
# 39                      Unweighted base                 Unweighted base
# 40  0.094                           NaN                         % agree
# 41  0.434                           NaN    % neither agree nor disagree
# 42  0.472                           NaN  % Disagree / strongly disagree
# 43    917                           NaN                 Unweighted base
# 44  0.084                           NaN                         % agree
# 45  0.443                           NaN    % neither agree nor disagree
# 46  0.472                           NaN  % Disagree / strongly disagree
# 47   1078                           NaN                 Unweighted base
#
#            Alcohol2                 Alcohol issue    Year  \
# 0              None                          None  2016.0
# 1              None                          None  2016.0
# 2              None                          None  2016.0
# 3              None                          None  2016.0
# 4              None                          None  2015.0
# 5              None                          None  2015.0
# 6              None                          None  2015.0
# 7              None                          None  2015.0
# 8              None                          None  2016.0
# 9              None                          None  2016.0
# 10             None                          None  2016.0
# 11             None                          None  2016.0
# 12             None                          None  2015.0
# 13             None                          None  2015.0
# 14             None                          None  2015.0
# 15             None                          None  2015.0
# 16           Better                          None    Year
# 17   About the same                          None    Year
# 18            Worse                          None    Year
# 19  Unweighted base                          None    Year
# 20           Better                          None  2016.0
# 21   About the same                          None  2016.0
# 22            Worse                          None  2016.0
# 23  Unweighted base                          None  2016.0
# 24           Better                          None  2015.0
# 25   About the same                          None  2015.0
# 26            Worse                          None  2015.0
# 27  Unweighted base                          None  2015.0
# 28           Better                          None  2016.0
# 29   About the same                          None  2016.0
# 30            Worse                          None  2016.0
# 31  Unweighted base                          None  2016.0
# 32           Better                          None  2015.0
# 33   About the same                          None  2015.0
# 34            Worse                          None  2015.0
# 35  Unweighted base                          None  2015.0
# 36           Better  Total or a lot of confidence    Year
# 37   About the same               Some confidence    Year
# 38            Worse       Little or no confidence    Year
# 39  Unweighted base               Unweighted base    Year
# 40           Better  Total or a lot of confidence  2016.0
# 41   About the same               Some confidence  2016.0
# 42            Worse       Little or no confidence  2016.0
# 43  Unweighted base               Unweighted base  2016.0
# 44           Better  Total or a lot of confidence  2015.0
# 45   About the same               Some confidence  2015.0
# 46            Worse       Little or no confidence  2015.0
# 47  Unweighted base               Unweighted base  2015.0
#
#                                             Statement Measure Type    Unit
# 0   I am concerned about alcohol related issues in...   Percentage  People
# 1   I am concerned about alcohol related issues in...   Percentage  People
# 2   I am concerned about alcohol related issues in...   Percentage  People
# 3   I am concerned about alcohol related issues in...   Percentage  People
# 4   I am concerned about alcohol related issues in...   Percentage  People
# 5   I am concerned about alcohol related issues in...   Percentage  People
# 6   I am concerned about alcohol related issues in...   Percentage  People
# 7   I am concerned about alcohol related issues in...   Percentage  People
# 8   I am concerned about alcohol related issues in...   Percentage  People
# 9   I am concerned about alcohol related issues in...   Percentage  People
# 10  I am concerned about alcohol related issues in...   Percentage  People
# 11  I am concerned about alcohol related issues in...   Percentage  People
# 12  I am concerned about alcohol related issues in...   Percentage  People
# 13  I am concerned about alcohol related issues in...   Percentage  People
# 14  I am concerned about alcohol related issues in...   Percentage  People
# 15  I am concerned about alcohol related issues in...   Percentage  People
# 16  I am concerned about alcohol related issues in...   Percentage  People
# 17  I am concerned about alcohol related issues in...   Percentage  People
# 18  I am concerned about alcohol related issues in...   Percentage  People
# 19  I am concerned about alcohol related issues in...   Percentage  People
# 20        Alcohol related issues in the local area %    Percentage  People
# 21        Alcohol related issues in the local area %    Percentage  People
# 22        Alcohol related issues in the local area %    Percentage  People
# 23        Alcohol related issues in the local area %    Percentage  People
# 24        Alcohol related issues in the local area %    Percentage  People
# 25        Alcohol related issues in the local area %    Percentage  People
# 26        Alcohol related issues in the local area %    Percentage  People
# 27        Alcohol related issues in the local area %    Percentage  People
# 28        Alcohol related issues in the local area %    Percentage  People
# 29        Alcohol related issues in the local area %    Percentage  People
# 30        Alcohol related issues in the local area %    Percentage  People
# 31        Alcohol related issues in the local area %    Percentage  People
# 32        Alcohol related issues in the local area %    Percentage  People
# 33        Alcohol related issues in the local area %    Percentage  People
# 34        Alcohol related issues in the local area %    Percentage  People
# 35        Alcohol related issues in the local area %    Percentage  People
# 36        Alcohol related issues in the local area %    Percentage  People
# 37        Alcohol related issues in the local area %    Percentage  People
# 38        Alcohol related issues in the local area %    Percentage  People
# 39        Alcohol related issues in the local area %    Percentage  People
# 40                                                      Percentage  People
# 41                                                      Percentage  People
# 42                                                      Percentage  People
# 43                                                      Percentage  People
# 44                                                      Percentage  People
# 45                                                      Percentage  People
# 46                                                      Percentage  People
# 47                                                      Percentage  People

# %%
new_table['Statement'] = new_table['Statement'].map(
    lambda x: {
        '' : 'Overall level of confidence'
        }.get(x, x))

# %%
new_table.columns = ['Response' if x=='OBS' else x for x in new_table.columns]

# %%
new_table = new_table[new_table['Response'] != '']

# %%
new_table.dtypes
# Out:
# Response         object
# DATAMARKER       object
# Alcohol1         object
# Alcohol2         object
# Alcohol issue    object
# Year             object
# Statement        object
# Measure Type     object
# Unit             object
# dtype: object

# %%
new_table.tail(5)
# Out:
#    Response DATAMARKER                        Alcohol1         Alcohol2  \
# 43      917        NaN                 Unweighted base  Unweighted base
# 44    0.084        NaN                         % agree           Better
# 45    0.443        NaN    % neither agree nor disagree   About the same
# 46    0.472        NaN  % Disagree / strongly disagree            Worse
# 47     1078        NaN                 Unweighted base  Unweighted base
#
#                    Alcohol issue    Year                    Statement  \
# 43               Unweighted base  2016.0  Overall level of confidence
# 44  Total or a lot of confidence  2015.0  Overall level of confidence
# 45               Some confidence  2015.0  Overall level of confidence
# 46       Little or no confidence  2015.0  Overall level of confidence
# 47               Unweighted base  2015.0  Overall level of confidence
#
#    Measure Type    Unit
# 43   Percentage  People
# 44   Percentage  People
# 45   Percentage  People
# 46   Percentage  People
# 47   Percentage  People

# %%
new_table.head()
# Out:
#   Response DATAMARKER                        Alcohol1 Alcohol2 Alcohol issue  \
# 0     43.3        %**                         % agree     None          None
# 1    0.164        NaN    % neither agree nor disagree     None          None
# 2    0.403        NaN  % Disagree / strongly disagree     None          None
# 3      945        NaN                 Unweighted base     None          None
# 4    0.366        NaN                         % agree     None          None
#
#      Year                                          Statement Measure Type  \
# 0  2016.0  I am concerned about alcohol related issues in...   Percentage
# 1  2016.0  I am concerned about alcohol related issues in...   Percentage
# 2  2016.0  I am concerned about alcohol related issues in...   Percentage
# 3  2016.0  I am concerned about alcohol related issues in...   Percentage
# 4  2015.0  I am concerned about alcohol related issues in...   Percentage
#
#      Unit
# 0  People
# 1  People
# 2  People
# 3  People
# 4  People

# %%
def user_perc(x,y,z,p):
    
    if str(x) == 'I am concerned about alcohol related issues in my local area %':
        return y
    if str(x) == 'Alcohol related issues in the local area % ':
        return z 
    else:
        return p
    
new_table['Alcohol issue'] = new_table.apply(lambda row: user_perc(row['Statement'],row['Alcohol1'],row['Alcohol2'],row['Alcohol issue']), axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
new_table['Response'] = pd.to_numeric(new_table['Response'], errors='coerce')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Year'] = new_table['Year'].apply(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Response'] = new_table['Response'].apply(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def user_perc(x,y):
    
    if str(x) == 'Unweighted base':
        return 'Number'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Alcohol issue'],row['Measure Type']), axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table['Statement'] = new_table['Statement'].str.rstrip('%')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table = new_table[['Year','Alcohol issue','Statement','Measure Type','Response','Unit']]

# %%
new_table.head(5)
# Out:
#    Year                   Alcohol issue  \
# 0  2016                         % agree
# 1  2016    % neither agree nor disagree
# 2  2016  % Disagree / strongly disagree
# 3  2016                 Unweighted base
# 4  2015                         % agree
#
#                                            Statement Measure Type Response  \
# 0  I am concerned about alcohol related issues in...   Percentage     43.3
# 1  I am concerned about alcohol related issues in...   Percentage    0.164
# 2  I am concerned about alcohol related issues in...   Percentage    0.403
# 3  I am concerned about alcohol related issues in...       Number    945.0
# 4  I am concerned about alcohol related issues in...   Percentage    0.366
#
#      Unit
# 0  People
# 1  People
# 2  People
# 3  People
# 4  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('taba16.csv'), index = False)
